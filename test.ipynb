# %%
import os
import xml.etree.ElementTree as ET
from collections import defaultdict

def parse_story_files(story_folder):
    story_text_map = {}
    for file in os.listdir(story_folder):
        if file.startswith("Story_") and file.endswith(".xml"):
            tree = ET.parse(os.path.join(story_folder, file))
            root = tree.getroot()
            story_id = root.attrib.get("Self")
            texts = []
            for content in root.iter():
                if content.tag.endswith("Content"):
                    texts.append(content.text)
            if texts:
                story_text_map[story_id] = "\n".join(filter(None, texts))
    return story_text_map

def parse_spread_files(spread_folder):
    frames = []
    for file in os.listdir(spread_folder):
        if file.startswith("Spread_") and file.endswith(".xml"):
            tree = ET.parse(os.path.join(spread_folder, file))
            root = tree.getroot()

            for textframe in root.findall(".//TextFrame"):
                frame_info = {
                    "type": "text",
                    "id": textframe.attrib.get("Self"),
                    "story_id": textframe.attrib.get("ParentStory"),
                }
                frames.append(frame_info)

            for image in root.findall(".//Image"):
                image_id = image.attrib.get("Self")
                link = image.find(".//Link")
                link_uri = link.attrib.get("LinkResourceURI") if link is not None else "unknown"
                frame_info = {
                    "type": "image",
                    "id": image_id,
                    "link_uri": link_uri
                }
                frames.append(frame_info)
    return frames

def extract_idml_content(idml_root):
    story_folder = os.path.join(idml_root, "Stories")
    spread_folder = os.path.join(idml_root, "Spreads")

    story_map = parse_story_files(story_folder)
    frames = parse_spread_files(spread_folder)

    output = []
    for frame in frames:
        if frame["type"] == "text":
            text = story_map.get(frame["story_id"], "[No text found]")
            output.append({
                "type": "text",
                "story_id": frame["story_id"],
                "frame_id": frame["id"],
                "content": text
            })
        elif frame["type"] == "image":
            output.append({
                "type": "image",
                "frame_id": frame["id"],
                "link_uri": frame["link_uri"]
            })

    return output

# === CONFIGURATION ===
idml_folder = "mc2410_068069ukCAa1a"  # Change this to your folder path

# === EXECUTION ===
result = extract_idml_content(idml_folder)

# === DISPLAY ===
for item in result:
    if item["type"] == "text":
        print(f"\n📝 Text Frame [{item['frame_id']}] (Story {item['story_id']}):\n{item['content']}")
    elif item["type"] == "image":
        print(f"\n🖼️ Image Frame [{item['frame_id']}]: linked to {item['link_uri']}")
# Out:
# 📝 Text Frame [u1e1b] (Story u1e1e):
# [No text found]
#
# 📝 Text Frame [u1be0] (Story u1be3):
# [No text found]
#
# 📝 Text Frame [u1bf8] (Story u1bfb):
# [No text found]
#
# 📝 Text Frame [u1db7] (Story u1dba):
# [No text found]
#
# 📝 Text Frame [u1dcf] (Story u1dd2):
# [No text found]
#
# 📝 Text Frame [u1de7] (Story u1dea):
# [No text found]
#
# 📝 Text Frame [u1dff] (Story u1e03):
# [No text found]
#
# 📝 Text Frame [u1e33] (Story u1e36):
# [No text found]
#
# 📝 Text Frame [u1e4b] (Story u1e36):
# [No text found]
#
# 📝 Text Frame [u1e4f] (Story u1e54):
# [No text found]
#
# 📝 Text Frame [u1ea7] (Story u1eaa):
# [No text found]
#
# 📝 Text Frame [u1ebf] (Story u1ec2):
# [No text found]
#
# 📝 Text Frame [u1ed7] (Story u1eda):
# [No text found]
#
# 📝 Text Frame [u1efb] (Story u1efe):
# [No text found]
#
# 📝 Text Frame [u1f13] (Story u1f16):
# [No text found]
#
# 📝 Text Frame [u1f2b] (Story u1f2e):
# [No text found]
#
# 📝 Text Frame [u1f46] (Story u1f49):
# [No text found]
#
# 📝 Text Frame [u1f5e] (Story u1f63):
# [No text found]
#
# 📝 Text Frame [u1f79] (Story u1f7c):
# [No text found]
#
# 🖼️ Image Frame [u2164]: linked to sc:615968
#
# 🖼️ Image Frame [u215d]: linked to sc:615976

# %%
import fitz
from pathlib import Path

# Paths
pdf_dir = "dataSources/2410/pdfs"
output_dir = "dataSources/2410/images"
path_pdf_dir = Path(pdf_dir)
path_output_dir = Path(output_dir)
path_output_dir.mkdir(parents=True, exist_ok=True)

# Loop over all PDF files in the folder
for pdf_path in sorted(path_pdf_dir.glob("*.pdf")):
    # Convert PDF to list of images (one per page)
    doc = fitz.open(pdf_path)
    page = doc[0]

    zoom = 2.0  # 2.0 → 150 DPI (approx)
    mat = fitz.Matrix(zoom, zoom)
    pix = page.get_pixmap(matrix=mat)

    # Save image
    image_path = path_output_dir / f"{pdf_path.stem}.jpg"
    pix.save(str(image_path))
    print(f"Saved: {image_path}")
# Out:
# Saved: dataSources\2410\images\fg2410_023.jpg
# Saved: dataSources\2410\images\fg2410_024.jpg
# Saved: dataSources\2410\images\fg2410_025.jpg
# Saved: dataSources\2410\images\fg2410_027.jpg
# Saved: dataSources\2410\images\fg2410_028.jpg
# Saved: dataSources\2410\images\fg2410_029.jpg
# Saved: dataSources\2410\images\fg2410_031.jpg
# Saved: dataSources\2410\images\fg2410_032.jpg
# Saved: dataSources\2410\images\fg2410_033.jpg
# Saved: dataSources\2410\images\fg2410_034.jpg
# Saved: dataSources\2410\images\fg2410_037.jpg
# Saved: dataSources\2410\images\fg2410_038.jpg
# Saved: dataSources\2410\images\fg2410_039.jpg
# Saved: dataSources\2410\images\fg2410_040.jpg
# Saved: dataSources\2410\images\fg2410_042.jpg
# Saved: dataSources\2410\images\fg2410_043.jpg
# Saved: dataSources\2410\images\fg2410_044.jpg
# Saved: dataSources\2410\images\fg2410_045.jpg
# Saved: dataSources\2410\images\fg2410_046.jpg
# Saved: dataSources\2410\images\fg2410_047.jpg
# Saved: dataSources\2410\images\fg2410_048.jpg
# Saved: dataSources\2410\images\fg2410_049.jpg
# Saved: dataSources\2410\images\fg2410_050.jpg
# Saved: dataSources\2410\images\fg2410_051.jpg
# Saved: dataSources\2410\images\fg2410_052.jpg
# Saved: dataSources\2410\images\fg2410_053.jpg
# Saved: dataSources\2410\images\fg2410_054.jpg
# Saved: dataSources\2410\images\fg2410_055.jpg
# Saved: dataSources\2410\images\fg2410_056.jpg
# Saved: dataSources\2410\images\fg2410_057.jpg
# Saved: dataSources\2410\images\fg2410_058.jpg
# Saved: dataSources\2410\images\fg2410_059.jpg
# Saved: dataSources\2410\images\fg2410_060.jpg
# Saved: dataSources\2410\images\fg2410_061.jpg
# Saved: dataSources\2410\images\fg2410_062.jpg
# Saved: dataSources\2410\images\fg2410_063.jpg
# Saved: dataSources\2410\images\fg2410_064.jpg
# Saved: dataSources\2410\images\fg2410_065.jpg
# Saved: dataSources\2410\images\fg2410_066.jpg
# Saved: dataSources\2410\images\fg2410_067.jpg
# Saved: dataSources\2410\images\fg2410_068.jpg
# Saved: dataSources\2410\images\fg2410_069.jpg
# Saved: dataSources\2410\images\fg2410_070.jpg
# Saved: dataSources\2410\images\fg2410_071.jpg
# Saved: dataSources\2410\images\fg2410_072.jpg
# Saved: dataSources\2410\images\fg2410_073.jpg
# Saved: dataSources\2410\images\fg2410_074.jpg
# Saved: dataSources\2410\images\fg2410_075.jpg
# Saved: dataSources\2410\images\fg2410_076.jpg
# Saved: dataSources\2410\images\fg2410_077.jpg
# Saved: dataSources\2410\images\fg2410_078.jpg
# Saved: dataSources\2410\images\fg2410_079.jpg
# Saved: dataSources\2410\images\fg2410_080.jpg
# Saved: dataSources\2410\images\fg2410_081.jpg
# Saved: dataSources\2410\images\fg2410_082.jpg
# Saved: dataSources\2410\images\fg2410_083.jpg
# Saved: dataSources\2410\images\fg2410_084.jpg
# Saved: dataSources\2410\images\fg2410_085.jpg
# Saved: dataSources\2410\images\fg2410_086.jpg
# Saved: dataSources\2410\images\fg2410_087.jpg
# Saved: dataSources\2410\images\fg2410_088.jpg
# Saved: dataSources\2410\images\fg2410_089.jpg
# Saved: dataSources\2410\images\fg2410_090.jpg
# Saved: dataSources\2410\images\fg2410_091.jpg
# Saved: dataSources\2410\images\fg2410_092.jpg
# Saved: dataSources\2410\images\fg2410_093.jpg
# Saved: dataSources\2410\images\fg2410_094.jpg
# Saved: dataSources\2410\images\fg2410_095.jpg
# Saved: dataSources\2410\images\fg2410_096.jpg
# Saved: dataSources\2410\images\fg2410_097.jpg
# Saved: dataSources\2410\images\fg2410_098.jpg
# Saved: dataSources\2410\images\fg2410_099.jpg
# Saved: dataSources\2410\images\fg2410_100.jpg
# Saved: dataSources\2410\images\fg2410_101.jpg
# Saved: dataSources\2410\images\fg2410_102.jpg
# Saved: dataSources\2410\images\fg2410_103.jpg
# Saved: dataSources\2410\images\fg2410_104.jpg
# Saved: dataSources\2410\images\fg2410_105.jpg
# Saved: dataSources\2410\images\fg2410_106.jpg
# Saved: dataSources\2410\images\fg2410_107.jpg
# Saved: dataSources\2410\images\fg2410_108.jpg
# Saved: dataSources\2410\images\fg2410_109.jpg
# Saved: dataSources\2410\images\fg2410_110.jpg
# Saved: dataSources\2410\images\fg2410_111.jpg
# Saved: dataSources\2410\images\fg2410_112.jpg
# Saved: dataSources\2410\images\fg2410_113.jpg
# Saved: dataSources\2410\images\fg2410_114.jpg
# Saved: dataSources\2410\images\fg2410_115.jpg
# Saved: dataSources\2410\images\fg2410_117.jpg
# Saved: dataSources\2410\images\fg2410_118.jpg
# Saved: dataSources\2410\images\fg2410_119.jpg
# Saved: dataSources\2410\images\fg2410_120.jpg
# Saved: dataSources\2410\images\fg2410_121.jpg
# Saved: dataSources\2410\images\fg2410_122.jpg
# Saved: dataSources\2410\images\fg2410_123.jpg
# Saved: dataSources\2410\images\fg2410_124.jpg
# Saved: dataSources\2410\images\fg2410_125.jpg
# Saved: dataSources\2410\images\fg2410_126.jpg
# Saved: dataSources\2410\images\fg2410_127.jpg
# Saved: dataSources\2410\images\fg2410_128.jpg
# Saved: dataSources\2410\images\fg2410_129.jpg
# Saved: dataSources\2410\images\fg2410_130.jpg
# Saved: dataSources\2410\images\fg2410_131.jpg
# Saved: dataSources\2410\images\fg2410_132.jpg
# Saved: dataSources\2410\images\fg2410_133.jpg
# Saved: dataSources\2410\images\fg2410_134.jpg
# Saved: dataSources\2410\images\fg2410_135.jpg
# Saved: dataSources\2410\images\fg2410_136.jpg
# Saved: dataSources\2410\images\fg2410_137.jpg
# Saved: dataSources\2410\images\fg2410_138.jpg
# Saved: dataSources\2410\images\fg2410_139.jpg
# Saved: dataSources\2410\images\fg2410_140.jpg
# Saved: dataSources\2410\images\fg2410_141.jpg
# Saved: dataSources\2410\images\fg2410_142.jpg
# Saved: dataSources\2410\images\fg2410_143.jpg
# Saved: dataSources\2410\images\fg2410_144.jpg
# Saved: dataSources\2410\images\fg2410_145.jpg
# Saved: dataSources\2410\images\fg2410_146.jpg
# Saved: dataSources\2410\images\fg2410_147.jpg
# Saved: dataSources\2410\images\fg2410_148.jpg
# Saved: dataSources\2410\images\fg2410_149.jpg
# Saved: dataSources\2410\images\fg2410_150.jpg
# Saved: dataSources\2410\images\fg2410_151.jpg
# Saved: dataSources\2410\images\fg2410_152.jpg
# Saved: dataSources\2410\images\fg2410_153.jpg
# Saved: dataSources\2410\images\fg2410_154.jpg
# Saved: dataSources\2410\images\fg2410_155.jpg
# Saved: dataSources\2410\images\fg2410_156.jpg
# Saved: dataSources\2410\images\fg2410_157.jpg
# Saved: dataSources\2410\images\fg2410_158.jpg
# Saved: dataSources\2410\images\fg2410_159.jpg
# Saved: dataSources\2410\images\fg2410_160.jpg
# Saved: dataSources\2410\images\fg2410_161.jpg
# Saved: dataSources\2410\images\fg2410_162.jpg
# Saved: dataSources\2410\images\fg2410_163.jpg
# Saved: dataSources\2410\images\fg2410_164.jpg
# Saved: dataSources\2410\images\fg2410_165.jpg
# Saved: dataSources\2410\images\fg2410_166.jpg
# Saved: dataSources\2410\images\fg2410_167.jpg
# Saved: dataSources\2410\images\fg2410_168.jpg
# Saved: dataSources\2410\images\fg2410_169.jpg
# Saved: dataSources\2410\images\fg2410_170.jpg
# Saved: dataSources\2410\images\fg2410_171.jpg
# Saved: dataSources\2410\images\fg2410_172.jpg
# Saved: dataSources\2410\images\fg2410_173.jpg
# Saved: dataSources\2410\images\fg2410_174.jpg
# Saved: dataSources\2410\images\fg2410_175.jpg
# Saved: dataSources\2410\images\fg2410_176.jpg
# Saved: dataSources\2410\images\fg2410_177.jpg
# Saved: dataSources\2410\images\fg2410_178.jpg
# Saved: dataSources\2410\images\fg2410_179.jpg
# Saved: dataSources\2410\images\fg2410_180.jpg
# Saved: dataSources\2410\images\fg2410_181.jpg
# Saved: dataSources\2410\images\fg2410_182.jpg
# Saved: dataSources\2410\images\fg2410_183.jpg
# Saved: dataSources\2410\images\fg2410_184.jpg
# Saved: dataSources\2410\images\fg2410_185.jpg
# Saved: dataSources\2410\images\fg2410_186.jpg
# Saved: dataSources\2410\images\fg2410_187.jpg
# Saved: dataSources\2410\images\fg2410_188.jpg
# Saved: dataSources\2410\images\fg2410_189.jpg
# Saved: dataSources\2410\images\fg2410_190.jpg
# Saved: dataSources\2410\images\fg2410_191.jpg
# Saved: dataSources\2410\images\fg2410_192.jpg
# Saved: dataSources\2410\images\fg2410_193.jpg
# Saved: dataSources\2410\images\fg2410_194.jpg
# Saved: dataSources\2410\images\fg2410_195.jpg
# Saved: dataSources\2410\images\fg2410_196.jpg
# Saved: dataSources\2410\images\fg2410_197.jpg
# Saved: dataSources\2410\images\fg2410_198.jpg
# Saved: dataSources\2410\images\fg2410_199.jpg
# Saved: dataSources\2410\images\fg2410_200.jpg
# Saved: dataSources\2410\images\fg2410_201.jpg
# Saved: dataSources\2410\images\fg2410_202.jpg
# Saved: dataSources\2410\images\fg2410_203.jpg
# Saved: dataSources\2410\images\fg2410_204.jpg
# Saved: dataSources\2410\images\fg2410_205.jpg
# Saved: dataSources\2410\images\fg2410_206.jpg
# Saved: dataSources\2410\images\fg2410_207.jpg
# Saved: dataSources\2410\images\fg2410_208.jpg
# Saved: dataSources\2410\images\fg2410_209.jpg
# Saved: dataSources\2410\images\fg2410_210.jpg
# Saved: dataSources\2410\images\fg2410_211.jpg
# Saved: dataSources\2410\images\fg2410_212.jpg
# Saved: dataSources\2410\images\fg2410_213.jpg
# Saved: dataSources\2410\images\fg2410_214.jpg
# Saved: dataSources\2410\images\fg2410_215.jpg
# Saved: dataSources\2410\images\fg2410_218.jpg
# Saved: dataSources\2410\images\fg2410_219.jpg
# Saved: dataSources\2410\images\fg2410_220.jpg
# Saved: dataSources\2410\images\fg2410_221.jpg
# Saved: dataSources\2410\images\fg2410_222.jpg
# Saved: dataSources\2410\images\fg2410_223.jpg
# Saved: dataSources\2410\images\fg2410_224.jpg
# Saved: dataSources\2410\images\fg2410_225.jpg
# Saved: dataSources\2410\images\fg2410_226.jpg
# Saved: dataSources\2410\images\fg2410_227.jpg
# Saved: dataSources\2410\images\fg2410_228.jpg
# Saved: dataSources\2410\images\fg2410_229.jpg
# Saved: dataSources\2410\images\fg2410_231.jpg
# Saved: dataSources\2410\images\fg2410_232.jpg
# Saved: dataSources\2410\images\fg2410_233.jpg
# Saved: dataSources\2410\images\fg2410_234.jpg
# Saved: dataSources\2410\images\fg2410_238.jpg
# Saved: dataSources\2410\images\fg2410_239.jpg
# Saved: dataSources\2410\images\fg2410_241.jpg
# Saved: dataSources\2410\images\fg2410_242.jpg
# Saved: dataSources\2410\images\fg2410_243.jpg
# Saved: dataSources\2410\images\fg2410_244.jpg
# Saved: dataSources\2410\images\fg2410_245.jpg
# Saved: dataSources\2410\images\fg2410_246.jpg
# Saved: dataSources\2410\images\fg2410_247.jpg
# Saved: dataSources\2410\images\fg2410_248.jpg
# Saved: dataSources\2410\images\fg2410_249.jpg
# Saved: dataSources\2410\images\fg2410_hagaki_omote.jpg
# Saved: dataSources\2410\images\fg2410_hagaki_ura.jpg

# %%
chunks = [
    "Introducing Tudor And The Marine Nationale Go Worldwide With The Pelagos FXD GMT 'Zulu Time'\nAn FXD for the skies.",
    "What We Know\nAt 12:00 Zulu Time, Tudor went hot with a new Pelagos FXD, a watch originally developed with the French Naval special forces unit Commando Hubert as a purpose-built tool for underwater navigation and buddy diving. That watch became a platform for a variety of releases, including sailing chronographs, cycling chronographs, and a bunch of others. Tudor has now gone back to the core inspiration for another watch built for the rigors of the Aéronautique Navale with a new GMT version of the Pelagos FXD.\nCased in Grade 2 titanium, measuring 42mm by 12.7mm with a 52mm lug-to-lug fixed strap-bar design, the watch looks and feels similar to several previous Tudor releases, all combined into one tough-looking package. The watch features a matte black dial and beige applied indices (with blue emission lume), an orange GMT hand (with green emission lume matching the GMT bezel), and red accents for the product name on the dial. The bezel is also in titanium with a ceramic bi-directional GMT insert. The caseback features the engraving 'M.N.24' (Marine Nationale 2024) as a callback to the original military-issued Tudors of the '70s and '80s.\nInside, you'll find the Manufacture Calibre MT5652-U automatic 'flyer' GMT movement with 65 hours of power reserve and an independent jumping hour GMT hand. It's also METAS-certified. The watch comes on a 'flight-suit green,' one-piece fabric strap with a grade 2 titanium pin buckle and keeper. It also has an extra removable fabric keeper with the French Naval Aviation roundel if you really want to lean into the French military theme. The watch is listed at $4,625 and isn't a limited edition.",
    "What We Think\nWhen Tudor started teasing this release, I was pretty certain it would be a titanium version of the FXD Chrono platform because of the emphasis they put on helicopters. A flyback chronograph for pilots would have made a lot of sense and shown the breadth of what the Marine Nationale and, specifically, the Commando Hubert do on a mission basis, including airborne insertions. On the other hand, the Pelagos FXD GMT makes a lot of sense as a complementary tool for every member of the team, especially when they're operating boots dry or just on station in a land-based combat zone.\nMy immediate reaction to the image on Instagram was that I had to get one as soon as possible. I regret not picking up the original Pelagos FXD with the M.N.21 caseback upon release, and as someone who wears a GMT almost daily, I've been waiting for the right Tudor GMT to join the collection. This is like a mashup of that original FXD M.N. and the LHD (Left-Hand Drive). When I saw it was the older MT5652 movement, I paused. It's a solid movement, with a flyer GMT, but the Black Bay Pro has that same movement and an interesting design but falls on the chunkier side.\nThe new Pelagos FXD GMT feels more reasonable, with a wider 42mm case but thinner at 12.7mm (versus 14.6mm for the Pro), which isn't too far off from my Rolex 126710BLRO. The larger case size might also balance out nicely with the Grade 2 Titanium. I'm going to wait to reserve final judgment (and payment) until I finally get my hands on one in person, but even more importantly, we should get a follow-up from Hodinkee's King of Tudor, James Stacey, as soon as he can get his Pelagos-loving hands on one.",
    "The Basics\nBrand: Tudor\nModel: Pelagos FXD GMT\nReference Number: 2542G247NU\nDiameter: 42mm\nThickness: 12.7mm\nLug-to-Lug: 52mm\nCase Material: Grade 2 titanium\nDial Color: Matte black\nIndexes: Beige applied hour markers with matching 'Snowflake' handset\nLume: Blue and green emission Super-LumiNova\nWater Resistance: 200mm\nStrap/Bracelet: Flight-suit green one-piece fabric strap with grade 2 titanium pin buckle and keeper; extra removable fabric keeper with the French Naval Aviation roundel",
    "The Movement\nCaliber: Manufacture Calibre MT5652-U\nFunctions: Hours, minutes, seconds, date, flyer GMT\nDiameter: 31.8mm\nThickness: 7.5mm\nPower Reserve: 65 hours\nWinding: Automatic\nFrequency: 28,800 vph\nJewels: 28 jewels\nChronometer Certified: Yes, METAS certification",
    "Pricing & Availability\nPrice: $4,625\nAvailability: Immediately\nLimited Edition: No\nFor more, click here.",
]
print(len(chunks))
# Out:
# 6

# %%
for i, chunk in enumerate(chunks):

    arr_previous_en = chunks[:i]
    previous_en = "\n\n".join(arr_previous_en)
    print(f'index :: {i}\nprevious en :: {previous_en}')
    # previous_jp = "\n\n".join(translated_chunks)
# Out:
# index :: 0
# previous en ::
# index :: 1
# previous en :: Introducing Tudor And The Marine Nationale Go Worldwide With The Pelagos FXD GMT 'Zulu Time'
# An FXD for the skies.
# index :: 2
# previous en :: Introducing Tudor And The Marine Nationale Go Worldwide With The Pelagos FXD GMT 'Zulu Time'
# An FXD for the skies.
#
# What We Know
# At 12:00 Zulu Time, Tudor went hot with a new Pelagos FXD, a watch originally developed with the French Naval special forces unit Commando Hubert as a purpose-built tool for underwater navigation and buddy diving. That watch became a platform for a variety of releases, including sailing chronographs, cycling chronographs, and a bunch of others. Tudor has now gone back to the core inspiration for another watch built for the rigors of the Aéronautique Navale with a new GMT version of the Pelagos FXD.
# Cased in Grade 2 titanium, measuring 42mm by 12.7mm with a 52mm lug-to-lug fixed strap-bar design, the watch looks and feels similar to several previous Tudor releases, all combined into one tough-looking package. The watch features a matte black dial and beige applied indices (with blue emission lume), an orange GMT hand (with green emission lume matching the GMT bezel), and red accents for the product name on the dial. The bezel is also in titanium with a ceramic bi-directional GMT insert. The caseback features the engraving 'M.N.24' (Marine Nationale 2024) as a callback to the original military-issued Tudors of the '70s and '80s.
# Inside, you'll find the Manufacture Calibre MT5652-U automatic 'flyer' GMT movement with 65 hours of power reserve and an independent jumping hour GMT hand. It's also METAS-certified. The watch comes on a 'flight-suit green,' one-piece fabric strap with a grade 2 titanium pin buckle and keeper. It also has an extra removable fabric keeper with the French Naval Aviation roundel if you really want to lean into the French military theme. The watch is listed at $4,625 and isn't a limited edition.
# index :: 3
# previous en :: Introducing Tudor And The Marine Nationale Go Worldwide With The Pelagos FXD GMT 'Zulu Time'
# An FXD for the skies.
#
# What We Know
# At 12:00 Zulu Time, Tudor went hot with a new Pelagos FXD, a watch originally developed with the French Naval special forces unit Commando Hubert as a purpose-built tool for underwater navigation and buddy diving. That watch became a platform for a variety of releases, including sailing chronographs, cycling chronographs, and a bunch of others. Tudor has now gone back to the core inspiration for another watch built for the rigors of the Aéronautique Navale with a new GMT version of the Pelagos FXD.
# Cased in Grade 2 titanium, measuring 42mm by 12.7mm with a 52mm lug-to-lug fixed strap-bar design, the watch looks and feels similar to several previous Tudor releases, all combined into one tough-looking package. The watch features a matte black dial and beige applied indices (with blue emission lume), an orange GMT hand (with green emission lume matching the GMT bezel), and red accents for the product name on the dial. The bezel is also in titanium with a ceramic bi-directional GMT insert. The caseback features the engraving 'M.N.24' (Marine Nationale 2024) as a callback to the original military-issued Tudors of the '70s and '80s.
# Inside, you'll find the Manufacture Calibre MT5652-U automatic 'flyer' GMT movement with 65 hours of power reserve and an independent jumping hour GMT hand. It's also METAS-certified. The watch comes on a 'flight-suit green,' one-piece fabric strap with a grade 2 titanium pin buckle and keeper. It also has an extra removable fabric keeper with the French Naval Aviation roundel if you really want to lean into the French military theme. The watch is listed at $4,625 and isn't a limited edition.
#
# What We Think
# When Tudor started teasing this release, I was pretty certain it would be a titanium version of the FXD Chrono platform because of the emphasis they put on helicopters. A flyback chronograph for pilots would have made a lot of sense and shown the breadth of what the Marine Nationale and, specifically, the Commando Hubert do on a mission basis, including airborne insertions. On the other hand, the Pelagos FXD GMT makes a lot of sense as a complementary tool for every member of the team, especially when they're operating boots dry or just on station in a land-based combat zone.
# My immediate reaction to the image on Instagram was that I had to get one as soon as possible. I regret not picking up the original Pelagos FXD with the M.N.21 caseback upon release, and as someone who wears a GMT almost daily, I've been waiting for the right Tudor GMT to join the collection. This is like a mashup of that original FXD M.N. and the LHD (Left-Hand Drive). When I saw it was the older MT5652 movement, I paused. It's a solid movement, with a flyer GMT, but the Black Bay Pro has that same movement and an interesting design but falls on the chunkier side.
# The new Pelagos FXD GMT feels more reasonable, with a wider 42mm case but thinner at 12.7mm (versus 14.6mm for the Pro), which isn't too far off from my Rolex 126710BLRO. The larger case size might also balance out nicely with the Grade 2 Titanium. I'm going to wait to reserve final judgment (and payment) until I finally get my hands on one in person, but even more importantly, we should get a follow-up from Hodinkee's King of Tudor, James Stacey, as soon as he can get his Pelagos-loving hands on one.
# index :: 4
# previous en :: Introducing Tudor And The Marine Nationale Go Worldwide With The Pelagos FXD GMT 'Zulu Time'
# An FXD for the skies.
#
# What We Know
# At 12:00 Zulu Time, Tudor went hot with a new Pelagos FXD, a watch originally developed with the French Naval special forces unit Commando Hubert as a purpose-built tool for underwater navigation and buddy diving. That watch became a platform for a variety of releases, including sailing chronographs, cycling chronographs, and a bunch of others. Tudor has now gone back to the core inspiration for another watch built for the rigors of the Aéronautique Navale with a new GMT version of the Pelagos FXD.
# Cased in Grade 2 titanium, measuring 42mm by 12.7mm with a 52mm lug-to-lug fixed strap-bar design, the watch looks and feels similar to several previous Tudor releases, all combined into one tough-looking package. The watch features a matte black dial and beige applied indices (with blue emission lume), an orange GMT hand (with green emission lume matching the GMT bezel), and red accents for the product name on the dial. The bezel is also in titanium with a ceramic bi-directional GMT insert. The caseback features the engraving 'M.N.24' (Marine Nationale 2024) as a callback to the original military-issued Tudors of the '70s and '80s.
# Inside, you'll find the Manufacture Calibre MT5652-U automatic 'flyer' GMT movement with 65 hours of power reserve and an independent jumping hour GMT hand. It's also METAS-certified. The watch comes on a 'flight-suit green,' one-piece fabric strap with a grade 2 titanium pin buckle and keeper. It also has an extra removable fabric keeper with the French Naval Aviation roundel if you really want to lean into the French military theme. The watch is listed at $4,625 and isn't a limited edition.
#
# What We Think
# When Tudor started teasing this release, I was pretty certain it would be a titanium version of the FXD Chrono platform because of the emphasis they put on helicopters. A flyback chronograph for pilots would have made a lot of sense and shown the breadth of what the Marine Nationale and, specifically, the Commando Hubert do on a mission basis, including airborne insertions. On the other hand, the Pelagos FXD GMT makes a lot of sense as a complementary tool for every member of the team, especially when they're operating boots dry or just on station in a land-based combat zone.
# My immediate reaction to the image on Instagram was that I had to get one as soon as possible. I regret not picking up the original Pelagos FXD with the M.N.21 caseback upon release, and as someone who wears a GMT almost daily, I've been waiting for the right Tudor GMT to join the collection. This is like a mashup of that original FXD M.N. and the LHD (Left-Hand Drive). When I saw it was the older MT5652 movement, I paused. It's a solid movement, with a flyer GMT, but the Black Bay Pro has that same movement and an interesting design but falls on the chunkier side.
# The new Pelagos FXD GMT feels more reasonable, with a wider 42mm case but thinner at 12.7mm (versus 14.6mm for the Pro), which isn't too far off from my Rolex 126710BLRO. The larger case size might also balance out nicely with the Grade 2 Titanium. I'm going to wait to reserve final judgment (and payment) until I finally get my hands on one in person, but even more importantly, we should get a follow-up from Hodinkee's King of Tudor, James Stacey, as soon as he can get his Pelagos-loving hands on one.
#
# The Basics
# Brand: Tudor
# Model: Pelagos FXD GMT
# Reference Number: 2542G247NU
# Diameter: 42mm
# Thickness: 12.7mm
# Lug-to-Lug: 52mm
# Case Material: Grade 2 titanium
# Dial Color: Matte black
# Indexes: Beige applied hour markers with matching 'Snowflake' handset
# Lume: Blue and green emission Super-LumiNova
# Water Resistance: 200mm
# Strap/Bracelet: Flight-suit green one-piece fabric strap with grade 2 titanium pin buckle and keeper; extra removable fabric keeper with the French Naval Aviation roundel
# index :: 5
# previous en :: Introducing Tudor And The Marine Nationale Go Worldwide With The Pelagos FXD GMT 'Zulu Time'
# An FXD for the skies.
#
# What We Know
# At 12:00 Zulu Time, Tudor went hot with a new Pelagos FXD, a watch originally developed with the French Naval special forces unit Commando Hubert as a purpose-built tool for underwater navigation and buddy diving. That watch became a platform for a variety of releases, including sailing chronographs, cycling chronographs, and a bunch of others. Tudor has now gone back to the core inspiration for another watch built for the rigors of the Aéronautique Navale with a new GMT version of the Pelagos FXD.
# Cased in Grade 2 titanium, measuring 42mm by 12.7mm with a 52mm lug-to-lug fixed strap-bar design, the watch looks and feels similar to several previous Tudor releases, all combined into one tough-looking package. The watch features a matte black dial and beige applied indices (with blue emission lume), an orange GMT hand (with green emission lume matching the GMT bezel), and red accents for the product name on the dial. The bezel is also in titanium with a ceramic bi-directional GMT insert. The caseback features the engraving 'M.N.24' (Marine Nationale 2024) as a callback to the original military-issued Tudors of the '70s and '80s.
# Inside, you'll find the Manufacture Calibre MT5652-U automatic 'flyer' GMT movement with 65 hours of power reserve and an independent jumping hour GMT hand. It's also METAS-certified. The watch comes on a 'flight-suit green,' one-piece fabric strap with a grade 2 titanium pin buckle and keeper. It also has an extra removable fabric keeper with the French Naval Aviation roundel if you really want to lean into the French military theme. The watch is listed at $4,625 and isn't a limited edition.
#
# What We Think
# When Tudor started teasing this release, I was pretty certain it would be a titanium version of the FXD Chrono platform because of the emphasis they put on helicopters. A flyback chronograph for pilots would have made a lot of sense and shown the breadth of what the Marine Nationale and, specifically, the Commando Hubert do on a mission basis, including airborne insertions. On the other hand, the Pelagos FXD GMT makes a lot of sense as a complementary tool for every member of the team, especially when they're operating boots dry or just on station in a land-based combat zone.
# My immediate reaction to the image on Instagram was that I had to get one as soon as possible. I regret not picking up the original Pelagos FXD with the M.N.21 caseback upon release, and as someone who wears a GMT almost daily, I've been waiting for the right Tudor GMT to join the collection. This is like a mashup of that original FXD M.N. and the LHD (Left-Hand Drive). When I saw it was the older MT5652 movement, I paused. It's a solid movement, with a flyer GMT, but the Black Bay Pro has that same movement and an interesting design but falls on the chunkier side.
# The new Pelagos FXD GMT feels more reasonable, with a wider 42mm case but thinner at 12.7mm (versus 14.6mm for the Pro), which isn't too far off from my Rolex 126710BLRO. The larger case size might also balance out nicely with the Grade 2 Titanium. I'm going to wait to reserve final judgment (and payment) until I finally get my hands on one in person, but even more importantly, we should get a follow-up from Hodinkee's King of Tudor, James Stacey, as soon as he can get his Pelagos-loving hands on one.
#
# The Basics
# Brand: Tudor
# Model: Pelagos FXD GMT
# Reference Number: 2542G247NU
# Diameter: 42mm
# Thickness: 12.7mm
# Lug-to-Lug: 52mm
# Case Material: Grade 2 titanium
# Dial Color: Matte black
# Indexes: Beige applied hour markers with matching 'Snowflake' handset
# Lume: Blue and green emission Super-LumiNova
# Water Resistance: 200mm
# Strap/Bracelet: Flight-suit green one-piece fabric strap with grade 2 titanium pin buckle and keeper; extra removable fabric keeper with the French Naval Aviation roundel
#
# The Movement
# Caliber: Manufacture Calibre MT5652-U
# Functions: Hours, minutes, seconds, date, flyer GMT
# Diameter: 31.8mm
# Thickness: 7.5mm
# Power Reserve: 65 hours
# Winding: Automatic
# Frequency: 28,800 vph
# Jewels: 28 jewels
# Chronometer Certified: Yes, METAS certification

# %%
import json

def format_label_studio_for_donut(label_studio_json_path, output_jsonl_path, image_dir_prefix=""):
    """
    Converts Label Studio JSON export to JSONL format for Donut model fine-tuning.
    Handles a 'PageIndex' label by including it in 'gt_parses' by default,
    or can be modified to extract it as a top-level key.

    Args:
        label_studio_json_path (str): Path to the Label Studio exported JSON file.
        output_jsonl_path (str): Path to save the formatted JSONL file.
        image_dir_prefix (str): Optional prefix for image file names
                                (e.g., "path/to/your/images/").
    """
    formatted_data = []

    with open(label_studio_json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    for task in data:
        if not task.get('annotations'):
            print(f"Skipping task ID {task.get('id')} as it has no annotations.")
            continue

        annotation = task['annotations'][0]
        results = annotation['result']

        image_file_name = task.get('file_upload')
        if not image_file_name:
            image_path_in_label_studio = task.get('data', {}).get('image', "")
            if image_path_in_label_studio:
                image_file_name = image_path_in_label_studio.split('/')[-1]
            else:
                print(f"Warning: Could not determine image file name for task ID {task.get('id')}")
                image_file_name = f"unknown_image_{task.get('id')}.jpg"

        full_image_path = f"{image_dir_prefix}{image_file_name}"

        bboxes_info = {}
        texts_info = {}

        for res_item in results:
            item_id = res_item.get('id')
            if not item_id:
                continue

            if res_item['type'] == 'rectanglelabels' and 'value' in res_item and 'rectanglelabels' in res_item['value']:
                label = res_item['value']['rectanglelabels'][0]
                bboxes_info[item_id] = {"label": label}
            elif res_item['type'] == 'textarea' and 'value' in res_item and 'text' in res_item['value']:
                text_content = "\n".join(res_item['value']['text'])
                texts_info[item_id] = {"text": text_content}

        gt_parses_list = []
        page_index_text = None # For extracting PageIndex as a separate field

        for item_id, bbox_data in bboxes_info.items():
            if item_id in texts_info:
                label = bbox_data["label"]
                text = texts_info[item_id]["text"]

                # --- Optional: Modification for PageIndex as a separate field ---
                # If you want PageIndex as a top-level key like "page_index": "123"
                # in the ground_truth JSON, uncomment and adapt the following:
                #
                # if label.lower() == 'pageindex':
                #     page_index_text = text
                #     # Optionally, skip adding it to gt_parses_list if it's top-level only
                #     # continue
                # --- End Optional Modification ---

                gt_item = {
                    "label": label,
                    "text": text
                }
                gt_parses_list.append(gt_item)
            else:
                # Handle cases where a bbox might not have corresponding text
                label = bbox_data["label"]
                gt_item = {
                    "label": label,
                    "text": "" # Placeholder for image regions without text
                }
                # Allow "Image" (or similar visual-only labels) to have no text
                if label.lower() == "image":
                    gt_parses_list.append(gt_item)
                # If PageIndex must have text, it would fall into the warning below
                # Or, if PageIndex *can* be just a bbox without text (unlikely for page number):
                # elif label.lower() == 'pageindex':
                #    gt_parses_list.append(gt_item) # If allowing PageIndex without text
                else:
                    print(f"Warning: Bounding box with ID {item_id} and label '{label}' has no corresponding text in task ID {task.get('id')} for image {image_file_name}.")

        # Create the ground_truth structure
        ground_truth_dict = {"gt_parses": gt_parses_list}

        # --- Optional: Add PageIndex as a top-level key if extracted ---
        # if page_index_text is not None:
        #     ground_truth_dict["page_index"] = page_index_text
        # --- End Optional ---
        
        ground_truth_json_string = json.dumps(ground_truth_dict, ensure_ascii=False)

        formatted_data.append({
            "file_name": full_image_path,
            "ground_truth": ground_truth_json_string
        })

    with open(output_jsonl_path, 'w', encoding='utf-8') as outfile:
        for entry in formatted_data:
            json.dump(entry, outfile, ensure_ascii=False)
            outfile.write('\n')

    print(f"Successfully formatted data and saved to {output_jsonl_path}")

# --- How to use ---
# 1. Save your Label Studio export as a .json file.
# 2. Update the paths in the example usage below.

# Example Usage:
# Use the filename of your updated JSON export
label_studio_file = 'project-1-at-2025-05-17-11-36-ccf01f10.json' # Path to your updated Label Studio JSON export
output_file = 'donut_finetune_data_with_pageindex.jsonl' # Desired output path

image_directory_prefix = "" # Adjust if needed, e.g., "data/fashion_magazines/"

# Ensure the JSON file is accessible by the script.
format_label_studio_for_donut(label_studio_file, output_file, image_directory_prefix)

# %%
import json

# Assuming `data` contains the loaded JSON structure
with open("outputs/bbre/fg2410_174175BbreA1.json", "r", encoding="utf-8") as f:
    data = json.load(f)

all_texts = []

# Iterate through each page
for page in data.get("pages", []):
    texts = page.get("texts", [])
    for text_entry in texts:
        content = text_entry.get("Content")
        if content:
            all_texts.append(content)

# Join and print all text content
full_text = "\n\n".join(all_texts)
print(full_text)

# Optional: Save to a file
with open("extracted_text.txt", "w", encoding="utf-8") as f:
    f.write(full_text)
# Out:
# 「 乳がん 」
# 最新白書
#
# 刻々と進化する最新知見情報をキャッチアップ！
#
# 9人に1人がかかる身近な病気である乳がん。
# 乳がん治療はここ十数年で大きく進化しています。
# 罹患者数は増えていますが、
# 早期乳がんの割合が半数を超え、
# 治るがんになりました。
# 最新情報を更新して、
# あなたのがん対策に役立ててください。流行中のハンサムを演出する女性に、
# スーツほど相応しいアイテムはないでしょう。
# イタリアの女性は上手にスーツを
# 着こなします。彼女たちはモード系や
# デザイナーズの服ばかりを着ているのでは
# ありません。ク１００wラシコイタリアが
# ブームになってから、テーラードスーツ姿の女性を
# 見かけることが多くなりました。彼女たち
#
# 取材・文＝増田美加（女性医療ジャーナリスト）
# イラスト＝River Rie（Softdesign）
# 写真協力＝Ggetty Iimages Shutterstock
# 編集＝石黒三惠（本誌）
#
# いま、乳がんは医療の発展に伴い、
# 治るがんに
# なっています。
# 乳がんほど、“患者ファースト”が
# 進んでいる
# 医療現場はありません。
# 心身ともに患者の負担を減らすための
# 個別化治療も進んでいます。
# 女性である以上、身近な病気であり続ける乳がん。
# 治療法も再建法も大きく進化していますが、
# 早期発見が何より
# 大切であることは変わっていません。
#
# が乳がんに罹患したのは２００６年、いまから18年前。乳がんの取材活動は約30年前から行っていますが、この十数年で乳がんの検診、治療、ケア現場は大きく変わったと思います。乳がんの医療者は、患者とともに治療を行っていく姿勢がほかのがん治療に比べて突出しています。乳がんは患者ファーストが最も進んでいるがん医療現場で、患者とのコミュニケーションを特に大事にします。乳がん治療の医療者間で急速に広がっている患者と医療者の共同意思決定「シェアード・ディシジョン・メイキング（ＳＤМ）」という考え方もそのことを表しています（Ｐ１７９参照）。
# その理由は、乳がんがほかのがんと比べて若い世代に多く、もの言う患者やサバイバーであるからかもしれません。ほかのがんは60代、70代、80代と年齢が上がるごとに増えていきますが、乳がんはちょっと違います。妊娠、出産前の若い年代にも発症し、ピークは働き盛りの40代から60代なのです（最近は70代以上の罹患も増えていますが）。年間9万人以上の女性が乳がんにかかっていますが、そのうち0～Ⅰ期の早期の乳がんが5万人を超えています。比較的治りやすく、5年相対生存率は約92％と高く、Ⅰ期の早期乳がんなら約98％が治ります。治療後、元気に活動できる人がたくさんいるのです。そのため、患者自らが意見や経験を共有、発信し、医療の質を向上させる取り組みや活動を医療者とともに行っています。ピンクリボン運動がその代表ともいえるでしょう。
# 「乳がん検診を受けやすい環境整備をしてほしい」「遺伝や高濃度乳房などリスク別の乳がん検診を実現してほしい」「体に負担の少ない、乳房を切らない治療を受けたい」「自分に必要な効果のある最善の医療を受けたい」「がんになっても働きながら治療できる外見のケアをしてほしい」「抗がん薬で髪が抜けるのはイヤ」……。上げ続けているこんな声に、医療者は耳を傾け、医療は変わっていきました。
# 乳がん医療がどのように進歩し、いま現場ではどのような治療が行われているのか──。
# 次ページからは、患者のために乳がんの情報発信を続けている、若き乳腺専門医を取材しました。
# 流行中のハンサムを演出する女性に、スーツほど相応しいアイテムはないでしょう。イタリアの女性は上手にスーツを着こなします。彼女たちはモード系やデザイナーズの服ばかりを着ているのではありません。ク１００Ｗラシコイタリアがブームになってから、テーラードスーツ姿の女性を見かけることが多くなりました。彼女たちは、スーツを実に格好良く着こなし街を歩いています。スーツにブランドを表すアイコンは何一つあり２００Ｗません。しかし、彼女たちが着ているスーツが上質であることは一目瞭然です。体にフィットしているのは仕立てがいいから、品格の高さを感じさせるのは上質な生地を使用しているから。質のいいスーツのみが持３００Ｗっている独感が、オーラとなっているのです。スーツは趣味いい大人の女性だから着こなせるアイテムといえるでしょう。スーツには、スーツならではのメリットがあります。まず、体型カバー。スーツは不思議な４００Ｗ服で、少々メタボリ配が必要な年配者が着ても、それなりに似合ってしまうのです。相当似合うといってもいいかもしれません。ビヤ樽体型であろうと、短足であろうと、それを見事にカバーし、スタイル良くれる５００Ｗのです。さらに不思議なのは、スタイルがいいと、さらに魅力的になることでしょう。男女に関係なく、スーツを着こなす者のみがこの恩恵を受けられる。次に「コーディネートが楽」という点が挙げられます。基６００Ｗ本的にジャケッ何を合わせるかですが、女性がネクタイを締めるのは稀です。ニットであれシャツであれ、基本的に色に注意しながら合わせれば、失敗することはありません。そして次が一メリット。きちんとした７００Ｗ格好に見える。この形の服は、それなりに社会的責任を持った人が着る服といイメージがあります。女性代議士の多くがスーツを多用していることを見れば納得でしょう。ただし、彼女たちの色彩センスは参考に流８００Ｗ行中の「ハンサム」を演出する女性に、スーツほど相応しいアイテムはないでしょう。イタリアの女性は上手にスーツを着こなします。彼女たちはモード系やデザイナーズの服ばかりを着ているのではありません。９００Ｗクラシコイタリアがブームになってから、テーラードスーツ姿の女性を見かけることが多くなりました。彼女たちは、スーツを実に格好良く着こなし街を歩いています。スーツにブランドを表すアイコンは何一つ１０００Ｗ
#
# が乳がんに罹患したのは２００６年、いまから18年前。乳がんの取材活動は約30年前から行っていますが、この十数年で乳がんの検診、治療、ケア現場は大きく変わったと思います。乳がんの医療者は、患者とともに治療を行っていく姿勢がほかのがん治療に比べて突出しています。乳がんは患者ファーストが最も進んでいるがん医療現場で、患者とのコミュニケーションを特に大事にします。乳がん治療の医療者間で急速に広がっている患者と医療者の共同意思決定「シェアード・ディシジョン・メイキング（ＳＤМ）」という考え方もそのことを表しています（Ｐ１７９参照）。
# その理由は、乳がんがほかのがんと比べて若い世代に多く、もの言う患者やサバイバーであるからかもしれません。ほかのがんは60代、70代、80代と年齢が上がるごとに増えていきますが、乳がんはちょっと違います。妊娠、出産前の若い年代にも発症し、ピークは働き盛りの40代から60代なのです（最近は70代以上の罹患も増えていますが）。年間9万人以上の女性が乳がんにかかっていますが、そのうち0～Ⅰ期の早期の乳がんが5万人を超えています。比較的治りやすく、5年相対生存率は約92％と高く、Ⅰ期の早期乳がんなら約98％が治ります。治療後、元気に活動できる人がたくさんいるのです。そのため、患者自らが意見や経験を共有、発信し、医療の質を向上させる取り組みや活動を医療者とともに行っています。ピンクリボン運動がその代表ともいえるでしょう。
# 「乳がん検診を受けやすい環境整備をしてほしい」「遺伝や高濃度乳房などリスク別の乳がん検診を実現してほしい」「体に負担の少ない、乳房を切らない治療を受けたい」「自分に必要な効果のある最善の医療を受けたい」「がんになっても働きながら治療できる外見のケアをしてほしい」「抗がん薬で髪が抜けるのはイヤ」……。上げ続けているこんな声に、医療者は耳を傾け、医療は変わっていきました。
# 乳がん医療がどのように進歩し、いま現場ではどのような治療が行われているのか──。
# 次ページからは、患者のために乳がんの情報発信を続けている、若き乳腺専門医を取材しました。
# 流行中のハンサムを演出する女性に、スーツほど相応しいアイテムはないでしょう。イタリアの女性は上手にスーツを着こなします。彼女たちはモード系やデザイナーズの服ばかりを着ているのではありません。ク１００Ｗラシコイタリアがブームになってから、テーラードスーツ姿の女性を見かけることが多くなりました。彼女たちは、スーツを実に格好良く着こなし街を歩いています。スーツにブランドを表すアイコンは何一つあり２００Ｗません。しかし、彼女たちが着ているスーツが上質であることは一目瞭然です。体にフィットしているのは仕立てがいいから、品格の高さを感じさせるのは上質な生地を使用しているから。質のいいスーツのみが持３００Ｗっている独感が、オーラとなっているのです。スーツは趣味いい大人の女性だから着こなせるアイテムといえるでしょう。スーツには、スーツならではのメリットがあります。まず、体型カバー。スーツは不思議な４００Ｗ服で、少々メタボリ配が必要な年配者が着ても、それなりに似合ってしまうのです。相当似合うといってもいいかもしれません。ビヤ樽体型であろうと、短足であろうと、それを見事にカバーし、スタイル良くれる５００Ｗのです。さらに不思議なのは、スタイルがいいと、さらに魅力的になることでしょう。男女に関係なく、スーツを着こなす者のみがこの恩恵を受けられる。次に「コーディネートが楽」という点が挙げられます。基６００Ｗ本的にジャケッ何を合わせるかですが、女性がネクタイを締めるのは稀です。ニットであれシャツであれ、基本的に色に注意しながら合わせれば、失敗することはありません。そして次が一メリット。きちんとした７００Ｗ格好に見える。この形の服は、それなりに社会的責任を持った人が着る服といイメージがあります。女性代議士の多くがスーツを多用していることを見れば納得でしょう。ただし、彼女たちの色彩センスは参考に流８００Ｗ行中の「ハンサム」を演出する女性に、スーツほど相応しいアイテムはないでしょう。イタリアの女性は上手にスーツを着こなします。彼女たちはモード系やデザイナーズの服ばかりを着ているのではありません。９００Ｗクラシコイタリアがブームになってから、テーラードスーツ姿の女性を見かけることが多くなりました。彼女たちは、スーツを実に格好良く着こなし街を歩いています。スーツにブランドを表すアイコンは何一つ１０００Ｗ
#
# 私検
#
# P.17723
#
# 「高濃度乳房（デンスブレスト）」なら
# どんな検診が必要？
#
# 生活習慣としての
# 「ブレスト・アウェアネス」
# って何？
#
# 患者と医師の共同意思決定最善の治療法のための
# SDM（shared deicision making）
# って何？
#
# が乳がんに罹患したのは２００６年、いまから18年前。乳がんの取材活動は約30年前から行っていますが、この十数年で乳がんの検診、治療、ケア現場は大きく変わったと思います。乳がんの医療者は、患者とともに治療を行っていく姿勢がほかのがん治療に比べて突出しています。乳がんは患者ファーストが最も進んでいるがん医療現場で、患者とのコミュニケーションを特に大事にします。乳がん治療の医療者間で急速に広がっている患者と医療者の共同意思決定「シェアード・ディシジョン・メイキング（ＳＤМ）」という考え方もそのことを表しています（Ｐ１７９参照）。
# その理由は、乳がんがほかのがんと比べて若い世代に多く、もの言う患者やサバイバーであるからかもしれません。ほかのがんは60代、70代、80代と年齢が上がるごとに増えていきますが、乳がんはちょっと違います。妊娠、出産前の若い年代にも発症し、ピークは働き盛りの40代から60代なのです（最近は70代以上の罹患も増えていますが）。年間9万人以上の女性が乳がんにかかっていますが、そのうち0～Ⅰ期の早期の乳がんが5万人を超えています。比較的治りやすく、5年相対生存率は約92％と高く、Ⅰ期の早期乳がんなら約98％が治ります。治療後、元気に活動できる人がたくさんいるのです。そのため、患者自らが意見や経験を共有、発信し、医療の質を向上させる取り組みや活動を医療者とともに行っています。ピンクリボン運動がその代表ともいえるでしょう。
# 「乳がん検診を受けやすい環境整備をしてほしい」「遺伝や高濃度乳房などリスク別の乳がん検診を実現してほしい」「体に負担の少ない、乳房を切らない治療を受けたい」「自分に必要な効果のある最善の医療を受けたい」「がんになっても働きながら治療できる外見のケアをしてほしい」「抗がん薬で髪が抜けるのはイヤ」……。上げ続けているこんな声に、医療者は耳を傾け、医療は変わっていきました。
# 乳がん医療がどのように進歩し、いま現場ではどのような治療が行われているのか──。
# 次ページからは、患者のために乳がんの情報発信を続けている、若き乳腺専門医を取材しました。
# 流行中のハンサムを演出する女性に、スーツほど相応しいアイテムはないでしょう。イタリアの女性は上手にスーツを着こなします。彼女たちはモード系やデザイナーズの服ばかりを着ているのではありません。ク１００Ｗラシコイタリアがブームになってから、テーラードスーツ姿の女性を見かけることが多くなりました。彼女たちは、スーツを実に格好良く着こなし街を歩いています。スーツにブランドを表すアイコンは何一つあり２００Ｗません。しかし、彼女たちが着ているスーツが上質であることは一目瞭然です。体にフィットしているのは仕立てがいいから、品格の高さを感じさせるのは上質な生地を使用しているから。質のいいスーツのみが持３００Ｗっている独感が、オーラとなっているのです。スーツは趣味いい大人の女性だから着こなせるアイテムといえるでしょう。スーツには、スーツならではのメリットがあります。まず、体型カバー。スーツは不思議な４００Ｗ服で、少々メタボリ配が必要な年配者が着ても、それなりに似合ってしまうのです。相当似合うといってもいいかもしれません。ビヤ樽体型であろうと、短足であろうと、それを見事にカバーし、スタイル良くれる５００Ｗのです。さらに不思議なのは、スタイルがいいと、さらに魅力的になることでしょう。男女に関係なく、スーツを着こなす者のみがこの恩恵を受けられる。次に「コーディネートが楽」という点が挙げられます。基６００Ｗ本的にジャケッ何を合わせるかですが、女性がネクタイを締めるのは稀です。ニットであれシャツであれ、基本的に色に注意しながら合わせれば、失敗することはありません。そして次が一メリット。きちんとした７００Ｗ格好に見える。この形の服は、それなりに社会的責任を持った人が着る服といイメージがあります。女性代議士の多くがスーツを多用していることを見れば納得でしょう。ただし、彼女たちの色彩センスは参考に流８００Ｗ行中の「ハンサム」を演出する女性に、スーツほど相応しいアイテムはないでしょう。イタリアの女性は上手にスーツを着こなします。彼女たちはモード系やデザイナーズの服ばかりを着ているのではありません。９００Ｗクラシコイタリアがブームになってから、テーラードスーツ姿の女性を見かけることが多くなりました。彼女たちは、スーツを実に格好良く着こなし街を歩いています。スーツにブランドを表すアイコンは何一つ１０００Ｗ
#
# 増田美加さん
#
# ますだみかおかべみよじ●流当事者視点に立った女性のヘルスケアや医療情報について執筆、講演を行う。13年間続く小誌医療連載「婦人画報婦人科」や「婦人画報プレミアム」の動画連載「名医の養生法」も好評。乳がんサバイバーでもある。行中のハンサムを演出する女性に、スーツほど相応しいアイテムはないでしょう。イタリアの女性は上手にスーツを着こなします。彼女たちはモード系やデザイナーズの服ばかりを着ているのではありません。ク１００Ｗラシコイタリアがブームになってから、テー
#
# 取材・執筆したのはお話を伺ったのは……
#
# （女性医療ジャーナリスト）
#
# 「乳がん」取材歴30★年 ！
# 女性医療ジャーナリスト・
# 増田美加さんが
# リレポートします ！
#
# P.18023
#
# P.17923
#
# P.18123
#
# P.17823
#
# P.17923
#
# 終末期だけではない、
# 本当の
# 緩和ケアって？
#
# 低侵襲の
# 切らずに治す手術をしない選択肢
# 「ラジオ波焼灼療法」って？
#
# 遺伝子検査解析（オンコタイプDX）の
# 進化で、
# オーダーメイド治療へ
#
# ＊参考資料／国立がん研究センター　がん情報サービス、
# 日本乳癌学会全国乳がん患者登録調査報告２０２０年
#
# 「名医の養生法」は
# こちらから！

# %%
import json
import argparse
import os

def sort_text_blocks(texts, tolerance=10):
    """
    Sorts a list of text block dictionaries based on natural reading order
    for Japanese magazines (top-to-bottom, right-to-left).

    Args:
        texts (list): A list of text dictionaries, each with a 'Bounds' key.
        tolerance (int, optional): The vertical tolerance in points to consider
                                   text blocks as being on the same line.
                                   Defaults to 10.

    Returns:
        list: The sorted list of text dictionaries.
    """
    if not texts:
        return []

    # Sort primarily by the top coordinate (y1) to establish vertical order
    texts.sort(key=lambda t: t['Bounds']['y1'])

    sorted_texts = []
    current_row = []
    if texts:
        current_row.append(texts[0])

    # Group texts into rows based on vertical proximity
    for i in range(1, len(texts)):
        prev_item = current_row[0]
        current_item = texts[i]
        # If the top of the current item is close to the top of the previous item,
        # consider them part of the same row.
        if abs(current_item['Bounds']['y1'] - prev_item['Bounds']['y1']) < tolerance:
            current_row.append(current_item)
        else:
            # Finalize the previous row: sort it right-to-left
            current_row.sort(key=lambda t: -t['Bounds']['x2']) # Sort by right edge, descending
            sorted_texts.extend(current_row)
            # Start a new row
            current_row = [current_item]

    # Don't forget to process the last row
    if current_row:
        current_row.sort(key=lambda t: -t['Bounds']['x2']) # Sort by right edge, descending
        sorted_texts.extend(current_row)
        
    return sorted_texts

input_file_path = 'outputs/kot/fg2410_054061kotB2a.json'

def test():
    try:
        with open(input_file_path, 'r', encoding='utf-8') as f:
                data = json.load(f)
        print(f"📄 Successfully read data from '{input_file_path}'")
    except (json.JSONDecodeError, IOError) as e:
            print(f"❌ Error reading or parsing JSON from '{input_file_path}': {e}")
            return

    if "pages" not in data:
        print("❌ Error: Input JSON does not contain a 'pages' key.")
        return

    # Process each page
    for page in data["pages"]:
        if "texts" in page and page["texts"]:
            print(f"  Sorting texts for page '{page.get('page_name', 'Unknown')}'...")
            sorted_texts_for_page = sort_text_blocks(page["texts"])
            texts = [item['Content'] for item in sorted_texts_for_page]
            print(f'----------\n{texts}')
            # page["texts"] = sorted_texts_for_page

test()
# Out:
# 📄 Successfully read data from 'outputs/kot/fg2410_054061kotB2a.json'
#   Sorting texts for page '054'...
# ----------
# ['第1章', '古いものを\n今様に楽しむ\n骨董術', '時間の試練に耐えて残ってきた古いものだけがもつ魅力。\nそれを博物館のガラス越しに眺めるのではなく、\n現代の生活に取り入れることにこそ、骨董の醍醐味があります。\nここでは４人の骨董の達人たちに、いままさに暮らしを\nともにしている骨董の品々を披露していただきました。ナヤド造船所でつくられた全長メートルの\nヨットアルバトロス号がスウェーデンの\n東南端にあるカルマー５０字出帆した。２回目の\n初心者でも骨董生活を始めたくなるヒントが満載です。長距離航海に乗り出したのはシ\nョーバーグ一家アイリー夫のヘンリック人の\n子供歳１００字ン９歳の', 'お手本は“骨董の達人”']
#   Sorting texts for page '055'...
# ----------
# ['“物”として強く、純粋な骨董。\n本当のお気に入りを華美でなく、\n生活に馴染むものを選んで使って、飾って、馴染んでいくう', '内田鋼一さん＆風知さん\n父［陶芸家］、娘［ミュージアム店長・菓子作家パティシエ］', '撮影＝木寺紀雄\u3000編集・文＝柏木敦子（本誌）', '日本スペイン製\n大正時代のたいしょ1900年代の木製ドア', '１８世紀0000年代のハンガリー製乳白カットガラス瓶\nハンガリー製ガラス瓶', 'かつてはゲストルームとして使っていたという広々としたリビングに、家具から器まで、さまざまな骨董が配されている。さていくつある？シンプルなかたちかつ黒色という黒色２０字あるスタイルに３０字だけに、どんな４０字マッチする懐深５０字っている。また６０字くりにヒールを７０字しているために８０字きやすいシンプルなかたちのにかつ１００字うシックなスタイル。それだけにど１２０字もマッチする懐の深さを持っている。また、厚めのつくり１５０字を周する航海計画を立てている小さなヨットの狭い空間に１８０字合う家族にとっては楽しいと同時に２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。あ判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たちの為に３００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳４００字']
#   Sorting texts for page '056'...
# ----------
# ['鋼一さんが\n今年スペインで\n出合った買った壺\n○○○○○', '私の「骨董履歴書」\n内田鋼剛一さん', '骨董歴は？', '37年', '初めてはじめて購入したものは？', '忘れてしまったけれど、古い車やオートバイが骨董への入り口。', '好きなジャンル・年代は？', '流行ではなく、自分の本当のお気に入りを見つけることシンプルなかたちに、かつ、黒色というシックなスタイル。３０字──鋼一さん', '和洋どちらも中世', 'あなたにとって骨董とは？', '歴史や風土を勉強させてくれる存在であり、／ロマン', 'スペイン・マドリードの蚤の市エリアにある骨董店で見つけた１5世紀の壺。曲線の美しさが際立つ。シンプルなかたちかつ黒色という黒色２０字あるスタイルに３０字だけに、どんな４０字マッチする懐深５０字っている。また６０字くりにヒールを７０字しているために８０字きやすいシンプルなかたちのにかつ１００字うシックなスタイル。それだけにど１２０字もマッチする懐の深さを持っている。また、厚めのつくり１５０字を周する航海計画を立てている小さなヨットの狭い空間に１８０字合う家族にとっては楽しいと同時に２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。あ判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たちの為に３００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳４００字']
#   Sorting texts for page '057'...
# ----------
# ['自分が納得できるもの、求めてすぐに使えるものを選ぶことシンプルなかたちに、かつ、黒色というシックなスタイル。３０字──風知さん', '風知さんが\n一番気に入っている\n北宋の輪花茶碗○○○○○', '私の「骨董履歴書」\n内田風知さん', '骨董歴は？', '１２年18歳から●年', '初めてはじめて購入したものは？', '一人暮らしを始めた東京・吉祥寺のとある骨董店で買った白い皿。', '好きなジャンル・年代は？', '生活に馴染むなじむ、きらびやかきらびやかでないものならなん何でも好き', 'あなたにとって骨董とは？', '昨年鋼一さんと訪れた日本の骨董市でひと目惚れ。「こんなにきれいな状態で残っているのは珍しいです」シンプルなかたちかつ黒色という黒色２０字あるスタイルに３０字だけに、どんな４０字マッチする懐深５０字っている。また６０字くりにヒールを７０字しているために８０字きやすいシンプルなかたちのにかつ１００字うシックなスタイル。それだけにど１２０字もマッチする懐の深さを持っている。また、厚めのつくり１５０字を周する航海計画を立てている小さなヨットの狭い空間に１８０字合う家族にとっては楽しいと同時に２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。あ判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たちの為に３００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳４００字', '生活の一部', 'fujingaho \ufeffoctober\ufeff']
#   Sorting texts for page '058'...
# ----------
# ['気に入ったものを選び、使って\n友達のように付き合う計算された小物選びで、\n誰もが振り向く姿に', '三重・四日市で作陶し、現代陶芸を牽引するだけでなく、アートディレクターや古美術収集家としても活躍する陶芸家・内田鋼一さん。あなたにとって骨董とは？と尋ねると、最初に口をついて出てきたのは「友達」という言葉でした。すぐに「いまのはなし」と取り消した鋼一さんでしたが、まるで友達のように自然に骨董と付き合い、暮らしているのが内田家の皆さんです。鋼一さんだけでなく、家族全員が骨董好き。なかでも長女の風知さんは「ファッションやコスメよりも圧倒的に骨董への出費が多いです」というほどの“骨董女子”です。\nやはりというべきか父娘の好みは似ていて、ふたりとも18歳から収集し始めたというのも同じ。「あまりゴージャスなもの、きらびやかなものは買わないですね。うちにシャンデリアは似合わないですから」と口を揃えます。時には娘が父のコレクションを購入したり、父が娘にプレゼントしたりすることもあるとか。\n鋼一さんはもともと古い車やオートバイが好きで、そこから自然と古い物＝骨董の世界に足を踏み入れたといいます。陶芸家として独立する前、韓国に始まり東南アジア、インド、西アフリカ、ヨーロッパを放浪してきた鋼一さん。なかでも古いスコップやシャベルが好きで、あちこちで買い集めたそうです。「木と金属という素材の組み合わせが物として美しいし、修繕の跡までも芸術的。彫刻は無理でもスコップはだいたい手ごろな値段でしたから収集しやすかったです」\nそんな父の英才教育を受け、いまや持っている器類の8割が骨董という風知さん。「作者がはっきりしない骨董は、物として純粋に向き合える気がします。物がよければそれがすべて。また、どうして昔にこんなモダンな絵付けや形が⁉という発見も楽しいです」というと、鋼一さんが「質感や経年変化は、いま作っている物では絶対に出せない。骨董品には長く残ってきた強さがあり、作り手としても刺激を受けます」と続けます。\nふたりの骨董選びの基準は、「流行や一般的な価値ではなく、自分が本当に気に入ったもの、納得できるものを選んで買う」。それをしまわずに使う、飾る。すると次はこんなものが欲しいなと自然に増え、生活に馴染んでいくといいます。\n今年6月、鋼一さん、風知さん、鋼一さんの妻で陶芸家の内田京子さん、3人の友人たちとともにスペインへ“骨董買い”の旅に出掛けました。サラゴサ、バルセロナ、バレンシア、セビリア、トレド、タラベラ、マドリードを2週間弱で巡る旅。簡単な予定は立てつつも、現地で見つけた骨董店や骨董市を積極的に訪れ、シエスタで休憩している場合は再開まで待つなど、毎日2万歩近く歩くほど旺盛な旅路に。「バルセロナやセビリア、バレンシアは昔からのやきものの産地も近く、それぞれの土地によさがあって充実した旅になりました」と鋼一さん。風知さんも「いわゆる西洋骨董はあまり買わないのですが、スペインでは素朴ですぐに使いたくなる骨董に多く出合えました」\nスペインからやって来た新しい“友達”とともに、内田家の骨董ライフは続いていきます。\nナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマー５０字出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳１００字ン９歳の息子オロフである彼等ヨーロッパを発って南米沖を通過し、難所のホーン岬を東から西へと回１５０字球を１周する航海計画を立てている小さなヨットの狭い空間に肩を寄せ合う家族にとっては楽しいと同２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。「判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たち一家の３００字について彼女が自分自身の考えを語ったものである。たくさんの人から何があなたがたをそんなに駆り３５０字何が何がと尋ねられるのよ。それに対するヘンリックと私の答えは同じではないけど、とにかく一緒に４００字うと決めたの。それは年に私たちがヨットでパナマ運河を通ってガラパゴス諸島に航海した当時はまだ４５０字１歳エリンは４歳家に戻ったのはで、エリンの小学校入学にぎりぎり間に合ったの。それでそのときの５００字陸上での生活は毎日がただ型にはまった仕事の連続で退屈そのものに感じられて次の冒険プランを練り５５０字７月日午後３時ちょうどに私たちはアルバトロス号で地球１周へと旅立ったの。だけどその前に何が私６００字り立てるのかという質問の答えに戻らなきゃね。私の場合、動機というのは、自分の人生に変化を持たせたいという気持ちと、ホーン岬は経験豊かでタフな男だけが挑戦できるものという一般の既成概念を一挙に打７００字いという、ささやかな衝迩の結びつきからね。子供連れの家族があの伝説化した岬を回ったら、みんなはどう言うでしょう。つまり、女たちも頑張ろう、ということ。問題は筋肉だけではなく精神的な強さも重要な８００字特別に頑健で力が強いわけではないけれど、日頃から物事を前向きに考えるよう鍛錬してきたつもりなの。時頭に浮かぶ恐ろしいイメージと戦って打ち勝つ必要があるわね。ときにはメートルにも達するホーン岬の９００字け、子供が船の外に落ちたらどうしようなんていう、恐怖心が頭をもたげてくることもあるし。でも、もしこんなことで怖じ気づくようなら、わざわざ危険なを選ぶことはなかったでしょうね。もう一度パナマ運１０００字航行していたでしょう。でも、私たちは前回のガラパゴス諸島への旅のときよりずっと性能の良い電子機器を装備したから、アルバトロス号を信頼しているわ。ヨットでの長い旅を夢見る夫に対し、乗り気じゃな１１００字そんな彼女たちに私はどれほどアドバイスしてあげたか分からない。いつも私は十分な判断力と決断力、そし字ユーモアがあれば大丈夫。大抵のことはそれで間に合いますって言ってやるのよ。今度の旅のスケジ１２００字いたい出来ているんだけど、突然、新しい魅力的な場所に寄ってみたくなることだってあるかも知れないわね。取りあえずカルマールの港を出帆してカナリア諸島に向かい、それからベルデ岬へ。計画では、ブラ１３００字バドールとリオデジャネイロに行き、そこで、クリスマスと年の新年を祝う。そして有名なウルグアイのル・エステに続いて、フォークランド諸島と、岩跳びペンギンたちを見てから、年の春ごろにはホーン岬を１４００字とりかかる。西に進路をとる前に、もし時間があればチリのパタゴニアとバルパライソにも立ち寄りたい。そ字てイースター島には、ちょうどイースターごろに着く予定にしているの。それから、ピッツケーン諸１５００字ア諸島、タヒチ、ボラボラ、トンガ、それに名前がなかなかうまく発音きない南海の島々にもぜひ立ち寄りた字と思っているわ。その後、計画ではオークランド、シドニー、そしてもちろん、グレートバリアリー１６００字もり。そこから、パプア・ニューギニア、バリ、クリスマス島、そしてスリランカ。年のクリスマスと年の新字はモルジブで祝いたいと思っているの。ヨーロッパには紅海とを通って戻るつもり。できればギリシ１７００字回航してから、フランスのニースにも立ち寄りたいな。最後はヨーロッパの運河を経由し、カルマールには日字ろに到着する予定。トータルで約海里、つまりキロメートルの長旅になるのよ。スウェーデンでは子１８００字も学校に通わせなくても大丈夫なの？って、よく尋ねられるんだけど、ええ、スウェーデンの義務教育に関する法律では問題ないの。国外にいると通学は義務づけられていないし、あとは状況に応じて親の責任で１９００字ばいい。私たちはエリンとオロフの船上での勉強にはきちんとした目標を決め、時間割も組んでいる。歳のエリンは旅の途中で６学年が始まり、９歳のオロフは船上で３学年が始まったの。ヘンリックが数学、物２０００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供２１００字Ｗン９歳の息子オロフである彼等ヨーロッパを発って南米沖を通過し、難所のホーン岬を東から西へと回って、地球を１周する航海計画を立てている小さなヨットの狭い空間に肩を寄せ合う家族にとっては楽しいと２２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。「判断力強靭な精神、それにユーモアのセンスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たち一家２３００字について彼女が自分自身の考えを語ったものである。たくさんの人から何があなたがたをそんなに駆り立てるの何が何がと尋ねられるのよ。それに対するヘンリックと私の答えは同じではないけど、とにかく一緒２４００字うと決めたの。それは年に私たちがヨットでパナマ運河を通ってガラパゴス諸島に航海した当時はまだオロフは１歳エリンは４歳家に戻ったので、エリンの小学校入学にぎりぎり間に合ったの。それでそのときの２５００字陸上での生活は毎日がただ型にはまった仕事の連続で退屈そのものに感じられて次の冒険プランを練り上げて年７月日午後３時ちょうどに私たちはアルバトロス号で地球１周へと旅立ったの。だけどその前に何が２６００字り立てるのかという質問の答えに戻らなきゃね。私の場合、動機というのは、自分の人生に変化を持たせたいという気持ちと、ホーン岬は経験豊かでタフな男だけが ...
#   Sorting texts for page '059'...
# ----------
# ['三重・四日市で作陶し、現代陶芸を牽引するだけでなく、アートディレクターや古美術収集家としても活躍する陶芸家・内田鋼一さん。あなたにとって骨董とは？と尋ねると、最初に口をついて出てきたのは「友達」という言葉でした。すぐに「いまのはなし」と取り消した鋼一さんでしたが、まるで友達のように自然に骨董と付き合い、暮らしているのが内田家の皆さんです。鋼一さんだけでなく、家族全員が骨董好き。なかでも長女の風知さんは「ファッションやコスメよりも圧倒的に骨董への出費が多いです」というほどの“骨董女子”です。\nやはりというべきか父娘の好みは似ていて、ふたりとも18歳から収集し始めたというのも同じ。「あまりゴージャスなもの、きらびやかなものは買わないですね。うちにシャンデリアは似合わないですから」と口を揃えます。時には娘が父のコレクションを購入したり、父が娘にプレゼントしたりすることもあるとか。\n鋼一さんはもともと古い車やオートバイが好きで、そこから自然と古い物＝骨董の世界に足を踏み入れたといいます。陶芸家として独立する前、韓国に始まり東南アジア、インド、西アフリカ、ヨーロッパを放浪してきた鋼一さん。なかでも古いスコップやシャベルが好きで、あちこちで買い集めたそうです。「木と金属という素材の組み合わせが物として美しいし、修繕の跡までも芸術的。彫刻は無理でもスコップはだいたい手ごろな値段でしたから収集しやすかったです」\nそんな父の英才教育を受け、いまや持っている器類の8割が骨董という風知さん。「作者がはっきりしない骨董は、物として純粋に向き合える気がします。物がよければそれがすべて。また、どうして昔にこんなモダンな絵付けや形が⁉という発見も楽しいです」というと、鋼一さんが「質感や経年変化は、いま作っている物では絶対に出せない。骨董品には長く残ってきた強さがあり、作り手としても刺激を受けます」と続けます。\nふたりの骨董選びの基準は、「流行や一般的な価値ではなく、自分が本当に気に入ったもの、納得できるものを選んで買う」。それをしまわずに使う、飾る。すると次はこんなものが欲しいなと自然に増え、生活に馴染んでいくといいます。\n今年6月、鋼一さん、風知さん、鋼一さんの妻で陶芸家の内田京子さん、3人の友人たちとともにスペインへ“骨董買い”の旅に出掛けました。サラゴサ、バルセロナ、バレンシア、セビリア、トレド、タラベラ、マドリードを2週間弱で巡る旅。簡単な予定は立てつつも、現地で見つけた骨董店や骨董市を積極的に訪れ、シエスタで休憩している場合は再開まで待つなど、毎日2万歩近く歩くほど旺盛な旅路に。「バルセロナやセビリア、バレンシアは昔からのやきものの産地も近く、それぞれの土地によさがあって充実した旅になりました」と鋼一さん。風知さんも「いわゆる西洋骨董はあまり買わないのですが、スペインでは素朴ですぐに使いたくなる骨董に多く出合えました」\nスペインからやって来た新しい“友達”とともに、内田家の骨董ライフは続いていきます。\nナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマー５０字出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳１００字ン９歳の息子オロフである彼等ヨーロッパを発って南米沖を通過し、難所のホーン岬を東から西へと回１５０字球を１周する航海計画を立てている小さなヨットの狭い空間に肩を寄せ合う家族にとっては楽しいと同２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。「判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たち一家の３００字について彼女が自分自身の考えを語ったものである。たくさんの人から何があなたがたをそんなに駆り３５０字何が何がと尋ねられるのよ。それに対するヘンリックと私の答えは同じではないけど、とにかく一緒に４００字うと決めたの。それは年に私たちがヨットでパナマ運河を通ってガラパゴス諸島に航海した当時はまだ４５０字１歳エリンは４歳家に戻ったのはで、エリンの小学校入学にぎりぎり間に合ったの。それでそのときの５００字陸上での生活は毎日がただ型にはまった仕事の連続で退屈そのものに感じられて次の冒険プランを練り５５０字７月日午後３時ちょうどに私たちはアルバトロス号で地球１周へと旅立ったの。だけどその前に何が私６００字り立てるのかという質問の答えに戻らなきゃね。私の場合、動機というのは、自分の人生に変化を持たせたいという気持ちと、ホーン岬は経験豊かでタフな男だけが挑戦できるものという一般の既成概念を一挙に打７００字いという、ささやかな衝迩の結びつきからね。子供連れの家族があの伝説化した岬を回ったら、みんなはどう言うでしょう。つまり、女たちも頑張ろう、ということ。問題は筋肉だけではなく精神的な強さも重要な８００字特別に頑健で力が強いわけではないけれど、日頃から物事を前向きに考えるよう鍛錬してきたつもりなの。時頭に浮かぶ恐ろしいイメージと戦って打ち勝つ必要があるわね。ときにはメートルにも達するホーン岬の９００字け、子供が船の外に落ちたらどうしようなんていう、恐怖心が頭をもたげてくることもあるし。でも、もしこんなことで怖じ気づくようなら、わざわざ危険なを選ぶことはなかったでしょうね。もう一度パナマ運１０００字航行していたでしょう。でも、私たちは前回のガラパゴス諸島への旅のときよりずっと性能の良い電子機器を装備したから、アルバトロス号を信頼しているわ。ヨットでの長い旅を夢見る夫に対し、乗り気じゃな１１００字そんな彼女たちに私はどれほどアドバイスしてあげたか分からない。いつも私は十分な判断力と決断力、そし字ユーモアがあれば大丈夫。大抵のことはそれで間に合いますって言ってやるのよ。今度の旅のスケジ１２００字いたい出来ているんだけど、突然、新しい魅力的な場所に寄ってみたくなることだってあるかも知れないわね。取りあえずカルマールの港を出帆してカナリア諸島に向かい、それからベルデ岬へ。計画では、ブラ１３００字バドールとリオデジャネイロに行き、そこで、クリスマスと年の新年を祝う。そして有名なウルグアイのル・エステに続いて、フォークランド諸島と、岩跳びペンギンたちを見てから、年の春ごろにはホーン岬を１４００字とりかかる。西に進路をとる前に、もし時間があればチリのパタゴニアとバルパライソにも立ち寄りたい。そ字てイースター島には、ちょうどイースターごろに着く予定にしているの。それから、ピッツケーン諸１５００字ア諸島、タヒチ、ボラボラ、トンガ、それに名前がなかなかうまく発音きない南海の島々にもぜひ立ち寄りた字と思っているわ。その後、計画ではオークランド、シドニー、そしてもちろん、グレートバリアリー１６００字もり。そこから、パプア・ニューギニア、バリ、クリスマス島、そしてスリランカ。年のクリスマスと年の新字はモルジブで祝いたいと思っているの。ヨーロッパには紅海とを通って戻るつもり。できればギリシ１７００字回航してから、フランスのニースにも立ち寄りたいな。最後はヨーロッパの運河を経由し、カルマールには日字ろに到着する予定。トータルで約海里、つまりキロメートルの長旅になるのよ。スウェーデンでは子１８００字も学校に通わせなくても大丈夫なの？って、よく尋ねられるんだけど、ええ、スウェーデンの義務教育に関する法律では問題ないの。国外にいると通学は義務づけられていないし、あとは状況に応じて親の責任で１９００字ばいい。私たちはエリンとオロフの船上での勉強にはきちんとした目標を決め、時間割も組んでいる。歳のエリンは旅の途中で６学年が始まり、９歳のオロフは船上で３学年が始まったの。ヘンリックが数学、物２０００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供２１００字Ｗン９歳の息子オロフである彼等ヨーロッパを発って南米沖を通過し、難所のホーン岬を東から西へと回って、地球を１周する航海計画を立てている小さなヨットの狭い空間に肩を寄せ合う家族にとっては楽しいと２２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。「判断力強靭な精神、それにユーモアのセンスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たち一家２３００字について彼女が自分自身の考えを語ったものである。たくさんの人から何があなたがたをそんなに駆り立てるの何が何がと尋ねられるのよ。それに対するヘンリックと私の答えは同じではないけど、とにかく一緒２４００字うと決めたの。それは年に私たちがヨットでパナマ運河を通ってガラパゴス諸島に航海した当時はまだオロフは１歳エリンは４歳家に戻ったので、エリンの小学校入学にぎりぎり間に合ったの。それでそのときの２５００字陸上での生活は毎日がただ型にはまった仕事の連続で退屈そのものに感じられて次の冒険プランを練り上げて年７月日午後３時ちょうどに私たちはアルバトロス号で地球１周へと旅立ったの。だけどその前に何が２６００字り立てるのかという質問の答えに戻らなきゃね。私の場合、動機というのは、自分の人生に変化を持たせたいという気持ちと、ホーン岬は経験豊かでタフな男だけが挑戦できるものという一般の既成概念を一挙に２７００字いという、ささやかな衝迩の結びつきからね。子供連れの ...
#   Sorting texts for page '060'...
# ----------
# ['三重・四日市で作陶し、現代陶芸を牽引するだけでなく、アートディレクターや古美術収集家としても活躍する陶芸家・内田鋼一さん。あなたにとって骨董とは？と尋ねると、最初に口をついて出てきたのは「友達」という言葉でした。すぐに「いまのはなし」と取り消した鋼一さんでしたが、まるで友達のように自然に骨董と付き合い、暮らしているのが内田家の皆さんです。鋼一さんだけでなく、家族全員が骨董好き。なかでも長女の風知さんは「ファッションやコスメよりも圧倒的に骨董への出費が多いです」というほどの“骨董女子”です。\nやはりというべきか父娘の好みは似ていて、ふたりとも18歳から収集し始めたというのも同じ。「あまりゴージャスなもの、きらびやかなものは買わないですね。うちにシャンデリアは似合わないですから」と口を揃えます。時には娘が父のコレクションを購入したり、父が娘にプレゼントしたりすることもあるとか。\n鋼一さんはもともと古い車やオートバイが好きで、そこから自然と古い物＝骨董の世界に足を踏み入れたといいます。陶芸家として独立する前、韓国に始まり東南アジア、インド、西アフリカ、ヨーロッパを放浪してきた鋼一さん。なかでも古いスコップやシャベルが好きで、あちこちで買い集めたそうです。「木と金属という素材の組み合わせが物として美しいし、修繕の跡までも芸術的。彫刻は無理でもスコップはだいたい手ごろな値段でしたから収集しやすかったです」\nそんな父の英才教育を受け、いまや持っている器類の8割が骨董という風知さん。「作者がはっきりしない骨董は、物として純粋に向き合える気がします。物がよければそれがすべて。また、どうして昔にこんなモダンな絵付けや形が⁉という発見も楽しいです」というと、鋼一さんが「質感や経年変化は、いま作っている物では絶対に出せない。骨董品には長く残ってきた強さがあり、作り手としても刺激を受けます」と続けます。\nふたりの骨董選びの基準は、「流行や一般的な価値ではなく、自分が本当に気に入ったもの、納得できるものを選んで買う」。それをしまわずに使う、飾る。すると次はこんなものが欲しいなと自然に増え、生活に馴染んでいくといいます。\n今年6月、鋼一さん、風知さん、鋼一さんの妻で陶芸家の内田京子さん、3人の友人たちとともにスペインへ“骨董買い”の旅に出掛けました。サラゴサ、バルセロナ、バレンシア、セビリア、トレド、タラベラ、マドリードを2週間弱で巡る旅。簡単な予定は立てつつも、現地で見つけた骨董店や骨董市を積極的に訪れ、シエスタで休憩している場合は再開まで待つなど、毎日2万歩近く歩くほど旺盛な旅路に。「バルセロナやセビリア、バレンシアは昔からのやきものの産地も近く、それぞれの土地によさがあって充実した旅になりました」と鋼一さん。風知さんも「いわゆる西洋骨董はあまり買わないのですが、スペインでは素朴ですぐに使いたくなる骨董に多く出合えました」\nスペインからやって来た新しい“友達”とともに、内田家の骨董ライフは続いていきます。\nナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマー５０字出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳１００字ン９歳の息子オロフである彼等ヨーロッパを発って南米沖を通過し、難所のホーン岬を東から西へと回１５０字球を１周する航海計画を立てている小さなヨットの狭い空間に肩を寄せ合う家族にとっては楽しいと同２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。「判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たち一家の３００字について彼女が自分自身の考えを語ったものである。たくさんの人から何があなたがたをそんなに駆り３５０字何が何がと尋ねられるのよ。それに対するヘンリックと私の答えは同じではないけど、とにかく一緒に４００字うと決めたの。それは年に私たちがヨットでパナマ運河を通ってガラパゴス諸島に航海した当時はまだ４５０字１歳エリンは４歳家に戻ったのはで、エリンの小学校入学にぎりぎり間に合ったの。それでそのときの５００字陸上での生活は毎日がただ型にはまった仕事の連続で退屈そのものに感じられて次の冒険プランを練り５５０字７月日午後３時ちょうどに私たちはアルバトロス号で地球１周へと旅立ったの。だけどその前に何が私６００字り立てるのかという質問の答えに戻らなきゃね。私の場合、動機というのは、自分の人生に変化を持たせたいという気持ちと、ホーン岬は経験豊かでタフな男だけが挑戦できるものという一般の既成概念を一挙に打７００字いという、ささやかな衝迩の結びつきからね。子供連れの家族があの伝説化した岬を回ったら、みんなはどう言うでしょう。つまり、女たちも頑張ろう、ということ。問題は筋肉だけではなく精神的な強さも重要な８００字特別に頑健で力が強いわけではないけれど、日頃から物事を前向きに考えるよう鍛錬してきたつもりなの。時頭に浮かぶ恐ろしいイメージと戦って打ち勝つ必要があるわね。ときにはメートルにも達するホーン岬の９００字け、子供が船の外に落ちたらどうしようなんていう、恐怖心が頭をもたげてくることもあるし。でも、もしこんなことで怖じ気づくようなら、わざわざ危険なを選ぶことはなかったでしょうね。もう一度パナマ運１０００字航行していたでしょう。でも、私たちは前回のガラパゴス諸島への旅のときよりずっと性能の良い電子機器を装備したから、アルバトロス号を信頼しているわ。ヨットでの長い旅を夢見る夫に対し、乗り気じゃな１１００字そんな彼女たちに私はどれほどアドバイスしてあげたか分からない。いつも私は十分な判断力と決断力、そし字ユーモアがあれば大丈夫。大抵のことはそれで間に合いますって言ってやるのよ。今度の旅のスケジ１２００字いたい出来ているんだけど、突然、新しい魅力的な場所に寄ってみたくなることだってあるかも知れないわね。取りあえずカルマールの港を出帆してカナリア諸島に向かい、それからベルデ岬へ。計画では、ブラ１３００字バドールとリオデジャネイロに行き、そこで、クリスマスと年の新年を祝う。そして有名なウルグアイのル・エステに続いて、フォークランド諸島と、岩跳びペンギンたちを見てから、年の春ごろにはホーン岬を１４００字とりかかる。西に進路をとる前に、もし時間があればチリのパタゴニアとバルパライソにも立ち寄りたい。そ字てイースター島には、ちょうどイースターごろに着く予定にしているの。それから、ピッツケーン諸１５００字ア諸島、タヒチ、ボラボラ、トンガ、それに名前がなかなかうまく発音きない南海の島々にもぜひ立ち寄りた字と思っているわ。その後、計画ではオークランド、シドニー、そしてもちろん、グレートバリアリー１６００字もり。そこから、パプア・ニューギニア、バリ、クリスマス島、そしてスリランカ。年のクリスマスと年の新字はモルジブで祝いたいと思っているの。ヨーロッパには紅海とを通って戻るつもり。できればギリシ１７００字回航してから、フランスのニースにも立ち寄りたいな。最後はヨーロッパの運河を経由し、カルマールには日字ろに到着する予定。トータルで約海里、つまりキロメートルの長旅になるのよ。スウェーデンでは子１８００字も学校に通わせなくても大丈夫なの？って、よく尋ねられるんだけど、ええ、スウェーデンの義務教育に関する法律では問題ないの。国外にいると通学は義務づけられていないし、あとは状況に応じて親の責任で１９００字ばいい。私たちはエリンとオロフの船上での勉強にはきちんとした目標を決め、時間割も組んでいる。歳のエリンは旅の途中で６学年が始まり、９歳のオロフは船上で３学年が始まったの。ヘンリックが数学、物２０００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供２１００字Ｗン９歳の息子オロフである彼等ヨーロッパを発って南米沖を通過し、難所のホーン岬を東から西へと回って、地球を１周する航海計画を立てている小さなヨットの狭い空間に肩を寄せ合う家族にとっては楽しいと２２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。「判断力強靭な精神、それにユーモアのセンスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たち一家２３００字について彼女が自分自身の考えを語ったものである。たくさんの人から何があなたがたをそんなに駆り立てるの何が何がと尋ねられるのよ。それに対するヘンリックと私の答えは同じではないけど、とにかく一緒２４００字うと決めたの。それは年に私たちがヨットでパナマ運河を通ってガラパゴス諸島に航海した当時はまだオロフは１歳エリンは４歳家に戻ったので、エリンの小学校入学にぎりぎり間に合ったの。それでそのときの２５００字陸上での生活は毎日がただ型にはまった仕事の連続で退屈そのものに感じられて次の冒険プランを練り上げて年７月日午後３時ちょうどに私たちはアルバトロス号で地球１周へと旅立ったの。だけどその前に何が２６００字り立てるのかという質問の答えに戻らなきゃね。私の場合、動機というのは、自分の人生に変化を持たせたいという気持ちと、ホーン岬は経験豊かでタフな男だけが挑戦できるものという一般の既成概念を一挙に２７００字いという、ささやかな衝迩の結びつきからね。子供連れの ...
#   Sorting texts for page '061'...
# ----------
# ['骨董豆知識【マニセス焼虫食い】14世紀ごろから16世紀ごろにかけ、イスラムの影響を受けてスペイン・バレンシア地方で発達した陶磁器の総称。陶土と釉薬の膨張率の違いから器の縁に素地が見える様。この子染付特有の様を茶人が見立てて、そう表した。', '１８００0000年代後半の\nスペイン製輪線八角りんせん皿', '「POPULART」で購入した輪線の八角皿（1800年代）に、風知さん手製のバスクチーズケーキを。染付の取り皿（17世紀）はバルセロナで。シンプルなかたちかつ黒色という黒色２０字あるスタイルに３０字だけに、どんな４０字マッチする懐深５０字っている。また６０字くりにヒールを７０字しているために８０字きやすいシンプルなかたちのにかつ１００字うシックなスタイル。それだけにど１２０字もマッチする懐の深さを持っている。また、厚めのつくり１５０字を周する航海計画を立てている小さなヨットの狭い空間に１８０字合う家族にとっては楽しいと同時に２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。あ判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たちの為に３００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳４００字', 'fujingaho \ufeffoctober\ufeff']

# %%
[
    "“物”として強く、純粋な骨董。\n本当のお気に入りを華美でなく、\n生活に馴染むものを選んで使って、飾って、馴染んでいくう",
    "内田鋼一さん＆風知さん\n父［陶芸家］、娘［ミュージアム店長・菓子作家パティシエ］",
    "撮影＝木寺紀雄\u3000編集・文＝柏木敦子（本誌）",
    "日本スペイン製\n大正時代のたいしょ1900年代の木製ドア",
    "１８世紀0000年代のハンガリー製乳白カットガラス瓶\nハンガリー製ガラス瓶",
    "かつてはゲストルームとして使っていたという広々としたリビングに、家具から器まで、さまざまな骨董が配されている。さていくつある？シンプルなかたちかつ黒色という黒色２０字あるスタイルに３０字だけに、どんな４０字マッチする懐深５０字っている。また６０字くりにヒールを７０字しているために８０字きやすいシンプルなかたちのにかつ１００字うシックなスタイル。それだけにど１２０字もマッチする懐の深さを持っている。また、厚めのつくり１５０字を周する航海計画を立てている小さなヨットの狭い空間に１８０字合う家族にとっては楽しいと同時に２００字に満ちた旅に違いないだが、アイリーショーバーグは楽天的に考える。あ判断力強靭な精神、それにユ２５０字センスがあれば問題ないはずよ以下は年の初これから最難関のホーン岬通過を前にして自分たちの為に３００字ナヤド造船所でつくられた全長メートルのヨットアルバトロス号がスウェーデンの東南端にあるカルマール港を出帆した。２回目の長距離航海に乗り出したのはショーバーグ一家アイリー夫のヘンリック人の子供歳４００字",
]

# %%
import json

with open("donut.json", "r") as file:
    data = json.load(file)

rose = None
for item in data:
    if item['id'] == 85:
        rose = item
        break
print(rose)
# Out:
# {'id': 85, 'annotations': [{'id': 70, 'completed_by': 1, 'result': [{'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 82.04716931843677, 'y': 9.071794412301044, 'width': 6.22688271387553, 'height': 26.477847347756757, 'rotation': 0, 'rectanglelabels': ['Title']}, 'id': '12u-5QZ7Bt', 'from_name': 'bbox', 'to_name': 'image', 'type': 'rectanglelabels', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 82.04716931843677, 'y': 9.071794412301044, 'width': 6.22688271387553, 'height': 26.477847347756757, 'rotation': 0, 'text': ['日本人とバラ']}, 'id': '12u-5QZ7Bt', 'from_name': 'text_content', 'to_name': 'image', 'type': 'textarea', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 68.4612433972538, 'y': 8.912055936562032, 'width': 12.858108461119599, 'height': 27.059068387097767, 'rotation': 0, 'rectanglelabels': ['TextBlock']}, 'id': 'Ng6ORmO3Vf', 'from_name': 'bbox', 'to_name': 'image', 'type': 'rectanglelabels', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 68.4612433972538, 'y': 8.912055936562032, 'width': 12.858108461119599, 'height': 27.059068387097767, 'rotation': 0, 'text': ['日本では、いつからバラが存在していたのでしょう。日本原種のバラが欧米のバラと交配されて新たな品種を生んだ歴史や、時代ごとの愛でられ方など、バラの育種に長年関わってきた矢口信好さんに伺いました。\\n お話を伺ったのは……\\n 矢口信好さん（元「京成バラ園」取締役・バラ園芸の指導講師）']}, 'id': 'Ng6ORmO3Vf', 'from_name': 'text_content', 'to_name': 'image', 'type': 'textarea', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 66.27779101706368, 'y': 8.912055936562032, 'width': 1.455634920126755, 'height': 9.945337784279372, 'rotation': 0, 'rectanglelabels': ['Entitle']}, 'id': 'pSdPMOjUYq', 'from_name': 'bbox', 'to_name': 'image', 'type': 'rectanglelabels', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 66.27779101706368, 'y': 8.912055936562032, 'width': 1.455634920126755, 'height': 9.945337784279372, 'rotation': 0, 'text': ['編集・文＝吉岡博恵（本誌）']}, 'id': 'pSdPMOjUYq', 'from_name': 'text_content', 'to_name': 'image', 'type': 'textarea', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 65.14563052363175, 'y': 40.23341194549382, 'width': 16.011984121394242, 'height': 7.103812703056689, 'rotation': 0, 'rectanglelabels': ['Caption']}, 'id': 'S5UbAVr7yO', 'from_name': 'bbox', 'to_name': 'image', 'type': 'rectanglelabels', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 65.14563052363175, 'y': 40.23341194549382, 'width': 16.011984121394242, 'height': 7.103812703056689, 'rotation': 0, 'text': ['牧野富太郎《富士薔薇》\\n 「霊峰の氣を受けて咲く富士薔薇」との記述が。「富士いばら」「フジイバラ」と命名。直径は15センチほど。高さ2～3メートルの落葉低木で主幹は太く小高木状になる。奇数羽状複葉が特徴。']}, 'id': 'S5UbAVr7yO', 'from_name': 'text_content', 'to_name': 'image', 'type': 'textarea', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 12.823642005742558, 'y': 65.22591663715691, 'width': 8.248597880718238, 'height': 0.7749613857880036, 'rotation': 0, 'rectanglelabels': ['InfoBox']}, 'id': 'GwWr7rDMdG', 'from_name': 'bbox', 'to_name': 'image', 'type': 'rectanglelabels', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 12.823642005742558, 'y': 65.22591663715691, 'width': 8.248597880718238, 'height': 0.7749613857880036, 'rotation': 0, 'text': ['提供：高知県立牧野植物園']}, 'id': 'GwWr7rDMdG', 'from_name': 'text_content', 'to_name': 'image', 'type': 'textarea', 'origin': 'manual'}, {'original_width': 1463, 'original_height': 1832, 'image_rotation': 0, 'value': {'x': 12.90557024637641, 'y': 10.934739260879766, 'width': 50.55668344222683, 'height': 53.7999440872025, 'rotation': 0, 'rectanglelabels': ['Image']}, 'id': '0kQ-vprGhc', 'from_name': 'bbox', 'to_name': 'image', 'type':  ...

# %%
annotation = rose.get('annotations')
first_item = annotation[0]
result = first_item.get('result')
grouped_annotations = {}
for item in result:
    original_width = item.get('original_width')
    original_height = item.get('original_height')
    value = item.get('value')
    if value:
        x = value.get('x')
        y = value.get('y')
        width = value.get('width')
        height = value.get('height')
        # 
        x1_abs = int(x/100*original_width)
        y1_abs = int(y/100*original_height)
        x2_abs = int((x+width)/100*original_width)
        y2_abs = int((y+height)/100*original_height)
        bbox = {'x1':x1_abs,'y1':y1_abs,'x2':x2_abs,'y2':y2_abs}
        print(f'value : {value}\nbbox : {bbox}')
    else:
        print('value is None')
# Out:
# value : {'x': 82.04716931843677, 'y': 9.071794412301044, 'width': 6.22688271387553, 'height': 26.477847347756757, 'rotation': 0, 'rectanglelabels': ['Title']}
# bbox : {'x1': 1200.35008712873, 'y1': 166.1952736333551, 'x2': 1291.449381232729, 'y2': 651.269437044259}
# value : {'x': 82.04716931843677, 'y': 9.071794412301044, 'width': 6.22688271387553, 'height': 26.477847347756757, 'rotation': 0, 'text': ['日本人とバラ']}
# bbox : {'x1': 1200.35008712873, 'y1': 166.1952736333551, 'x2': 1291.449381232729, 'y2': 651.269437044259}
# value : {'x': 68.4612433972538, 'y': 8.912055936562032, 'width': 12.858108461119599, 'height': 27.059068387097767, 'rotation': 0, 'rectanglelabels': ['TextBlock']}
# bbox : {'x1': 1001.587990901823, 'y1': 163.2688647578164, 'x2': 1189.7021176880028, 'y2': 658.9909976094476}
# value : {'x': 68.4612433972538, 'y': 8.912055936562032, 'width': 12.858108461119599, 'height': 27.059068387097767, 'rotation': 0, 'text': ['日本では、いつからバラが存在していたのでしょう。日本原種のバラが欧米のバラと交配されて新たな品種を生んだ歴史や、時代ごとの愛でられ方など、バラの育種に長年関わってきた矢口信好さんに伺いました。\\n お話を伺ったのは……\\n 矢口信好さん（元「京成バラ園」取締役・バラ園芸の指導講師）']}
# bbox : {'x1': 1001.587990901823, 'y1': 163.2688647578164, 'x2': 1189.7021176880028, 'y2': 658.9909976094476}
# value : {'x': 66.27779101706368, 'y': 8.912055936562032, 'width': 1.455634920126755, 'height': 9.945337784279372, 'rotation': 0, 'rectanglelabels': ['Entitle']}
# bbox : {'x1': 969.6440825796417, 'y1': 163.2688647578164, 'x2': 990.940021461096, 'y2': 345.4674529658145}
# value : {'x': 66.27779101706368, 'y': 8.912055936562032, 'width': 1.455634920126755, 'height': 9.945337784279372, 'rotation': 0, 'text': ['編集・文＝吉岡博恵（本誌）']}
# bbox : {'x1': 969.6440825796417, 'y1': 163.2688647578164, 'x2': 990.940021461096, 'y2': 345.4674529658145}
# value : {'x': 65.14563052363175, 'y': 40.23341194549382, 'width': 16.011984121394242, 'height': 7.103812703056689, 'rotation': 0, 'rectanglelabels': ['Caption']}
# bbox : {'x1': 953.0805745607324, 'y1': 737.0761068414467, 'x2': 1187.3359022567304, 'y2': 867.2179555614453}
# value : {'x': 65.14563052363175, 'y': 40.23341194549382, 'width': 16.011984121394242, 'height': 7.103812703056689, 'rotation': 0, 'text': ['牧野富太郎《富士薔薇》\\n 「霊峰の氣を受けて咲く富士薔薇」との記述が。「富士いばら」「フジイバラ」と命名。直径は15センチほど。高さ2～3メートルの落葉低木で主幹は太く小高木状になる。奇数羽状複葉が特徴。']}
# bbox : {'x1': 953.0805745607324, 'y1': 737.0761068414467, 'x2': 1187.3359022567304, 'y2': 867.2179555614453}
# value : {'x': 12.823642005742558, 'y': 65.22591663715691, 'width': 8.248597880718238, 'height': 0.7749613857880036, 'rotation': 0, 'rectanglelabels': ['InfoBox']}
# bbox : {'x1': 187.60988254401363, 'y1': 1194.9387927927146, 'x2': 308.28686953892145, 'y2': 1209.136085380351}
# value : {'x': 12.823642005742558, 'y': 65.22591663715691, 'width': 8.248597880718238, 'height': 0.7749613857880036, 'rotation': 0, 'text': ['提供：高知県立牧野植物園']}
# bbox : {'x1': 187.60988254401363, 'y1': 1194.9387927927146, 'x2': 308.28686953892145, 'y2': 1209.136085380351}
# value : {'x': 12.90557024637641, 'y': 10.934739260879766, 'width': 50.55668344222683, 'height': 53.7999440872025, 'rotation': 0, 'rectanglelabels': ['Image']}
# bbox : {'x1': 188.8084927044869, 'y1': 200.3244232593173, 'x2': 928.4527714642654, 'y2': 1185.9393989368668}
# value : {'x': 66.97659910340707, 'y': 50.28781945486849, 'width': 20.918904040388966, 'height': 18.306594719372235, 'rotation': 0, 'rectanglelabels': ['TextBlock']}
# bbox : {'x1': 979.8676448828453, 'y1': 921.2728524131907, 'x2': 1285.911210993736, 'y2': 1256.6496676720901}
# value : {'x': 66.97659910340707, 'y': 50.28781945486849, 'width': 20.918904040388966, 'height': 18.306594719372235, 'rotation': 0, 'text': ['世界で初めての育種家はあのジョゼフィーヌ\\n \u3000バラの歴史は古く、紀元前２000年、古代メソポタミアのバビロニアではすでに人類によって初めてのバラ栽培が行われていたという。同時期、クレタ島のミノス文明王朝時代の壁画にはバラが描かれ、中国では唐時代にやはり壁画や陶器などに美しいバラが描かれている。そして18世紀のフランス革命期、ナポレオン']}
# bbox : {'x1': 979.8676448828453, 'y1': 921.2728524131907, 'x2': 1285.911210993736, 'y2': 1256.6496676720901}
# value : {'x': 11.346981247880612, 'y': 70.9325757991823, 'width': 76.52927810820373, 'height': 18.30865647958801, 'rotation': 0, 'rectanglelabels': ['TextBlock']}
# bbox : {'x1': 166.00633565649335, 'y1': 1299.4847886410198, 'x2': 1285.6296743795137, 'y2': 1634.899375347072}
# value : {'x': 11.346981247880612, 'y': 70.9325757991823, 'width': 76.52927810820373, 'height': 18.30865647958801, 'rotation': 0, 'text': ['の皇后ジョゼフィーヌは、バラ好きが高じてマルメゾン宮殿に世界中からバラの原種や園芸種を集め、人工交配させた世界最初の“育種家”といわれている。始まりは25品種程度だったバラを、30年ほどかけて1829年には4000品種に増やしたという。\\n \u3000日本にも、古来15～20種ほどの原種のバラが自生していたとされ、最古の記録としては1300年前、奈良時代の『常陸国風土記』がある。朝廷に従わない豪族を退治するのに、茨で城を覆い侵入を防いだという由来があることから、常陸は明治維新後に「茨城」と命名された。茨とは原種の野ばらのことであり、特徴として花は2センチ程度の大きさで房には30～40ほどの“蕾”がつく。茨城県の県章は開き始めたバラの蕾をデザインしたもので、県花はバラであることは多くの方が知っていることであろう。\\n \u3000ほか、『万葉集』には「うまら」として、『枕草子』には「さうひ」としてバラが登場する。『源氏物語』の記述「階の底のさうひ春秋よりもしめやかに咲き」などから推測すると、すでに日本人の暮らしのなかでバラが愛でられる存在であったことが伝わってくる。さらに、古代種の原種のバラであれば一度しか咲かないため、このころすでに中国・雲南省や四川省から四季咲きのバラが到来していたのではないかと推測する研究者もいる。\\n \u3000鎌倉時代には、日本最古とされるバラの大和絵が『春日権現験記』に残されている。これは、春日大社の霊験を描く20巻の絵巻物で、狩衣や十二単の貴族たちが集う屋敷の庭に植えられた赤いバラが']}
# bbox : {'x1': 166.00633565649335, 'y1': 1299.4847886410198, 'x2': 1285.6296743795137, 'y2': 1634.899375347072}
# value : {'x': 88.92546269411643, 'y': 93.18834762331902, 'width': 2.2055074547374858, 'height': 1.1741839178605886, 'rotation': 0, 'rectanglelabels': ['PageIndex']}
# bbox : {'x1': 1300.9795192149234, 'y1': 1707.2105284592044, 'x2': 1333.2460932777328, 'y2': 1728.7215778344105}
# value : {'x': 88.92546269411643, 'y': 93.18834762331902, 'width': 2.2055074547374858, 'height': 1.1741839178605886, 'rotation': 0, 'text': ['102']}
# bbox : {'x1': 1300.9795192149234, 'y1': 1707.2105284592044, 'x2': 1333.2460932777328, 'y2': 1728.7215778344105}
# value is None
# value is None

# %%
import json
import uuid

# Load Label Studio export
with open("donut.json", "r", encoding="utf-8") as f:
    ls_data = json.load(f)

converted = []

for item in ls_data:
    result = item["annotations"][0]["result"]
    page_name = item["file_upload"].split("-")[-1].replace(".jpg", "").replace(".jpeg", "")

    texts = []
    images = []

    # Map to find textarea contents
    id_map = {r['id']: r for r in result if 'id' in r}

    # Find page_id from PageIndex
    page_id = None
    for r in result:
        if r["type"] == "rectanglelabels" and r["value"]["rectanglelabels"][0].lower() == "pageindex":
            text_result = next((t for t in result if t["type"] == "textarea" and t["id"] == r["id"]), None)
            if text_result:
                try:
                    page_id = int(text_result["value"]["text"][0].strip())
                except:
                    page_id = None
            break
    if page_id is None:
        page_id = -1  # fallback if pageindex is not found

    for r in result:
        if r["type"] == "rectanglelabels":
            bbox = r["value"]
            orig_w = r["original_width"]
            orig_h = r["original_height"]

            x1 = bbox["x"] * orig_w / 100
            y1 = bbox["y"] * orig_h / 100
            x2 = x1 + (bbox["width"] * orig_w / 100)
            y2 = y1 + (bbox["height"] * orig_h / 100)

            box = {
                "Bounds": {
                    "x1": x1,
                    "y1": y1,
                    "x2": x2,
                    "y2": y2
                }
            }

            label = r["value"]["rectanglelabels"][0]
            uid = str(uuid.uuid4())[:7]

            # Find corresponding text content
            matching_text = next(
                (t for t in result if t["type"] == "textarea" and t["id"] == r["id"]), None
            )
            content = matching_text["value"]["text"][0] if matching_text else ""

            if label.lower() == "image":
                box["URI"] = "sc:" + uid
                box["ImageId"] = uid
                images.append(box)
            elif label.lower() != "pageindex":
                box["Content"] = content
                box["TextId"] = uid
                texts.append(box)

    converted.append({
        "page_name": page_name,
        "page_id": page_id,
        "images": images,
        "texts": texts
    })

# Save output
with open("bbox_test.json", "w", encoding="utf-8") as f:
    json.dump(converted, f, indent=2, ensure_ascii=False)

# %% [markdown]
# ----- extract from idml file -----

# %%
import os
from extract_from_idml import extract

idmls_path = 'idmls'
out_path = 'outputs_idml_json'
idmls = os.listdir(idmls_path)
for folder_path in idmls:
    zips = os.listdir(os.path.join(idmls_path,folder_path))
    for zip_file in zips:
        idml_path = os.path.join(idmls_path,folder_path,zip_file)
        json_file = zip_file.replace('.zip','.json')
        output_path = os.path.join(out_path,folder_path,json_file)
        # print(f'idml file path : {idml_path}')
        # print(f'out path : {output_path}')
        extract(idml_path,output_path)

# %%
import cv2
import json
from PIL import Image, ImageDraw, ImageFont
import os
output_idml_json_path = 'outputs_idml_json'
original_width = 1463
original_height = 1832
margin = 50
page_width = 658
page_height = 842

for folder_path in os.listdir(output_idml_json_path):
    jsons = os.listdir(os.path.join(output_idml_json_path,folder_path))
    for json_file in jsons:
        with open(os.path.join(output_idml_json_path,folder_path,json_file), "r", encoding="utf-8") as f:
            json_obj = json.load(f)
        list_pages = json_obj['pages']
        for pages_json in list_pages:
            page_name = pages_json['page_name']
            # print(f'page name ---- {page_name}')
            img_path = f'fg2410_{page_name}.jpg'
            if os.path.exists(os.path.join('dataSources/2410/images',img_path)):
                pass
            else:
                print(f'image {img_path} do not exist')
            
            pass

# %%
# Crop image margin
from PIL import Image, ImageDraw, ImageFont
import os

folder_path = os.path.join("dataSources", "2410", "images")
margin = 50

for img_file in os.listdir(folder_path):
    img_path = os.path.join(folder_path, img_file)
    # print(img_path)
    image_ori = Image.open(img_path).convert("RGB")
    ori_width, ori_height = image_ori.size
    cropped_image = image_ori.crop(
        (margin, margin, ori_width - margin, ori_height - margin)
    )
    # cropped_image.show()
    cropped_image.save(img_path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 11
#       9 img_path = os.path.join(folder_path, img_file)
#      10 # print(img_path)
# ---> 11 image_ori = Image.open(img_path).convert("RGB")
#      12 ori_width, ori_height = image_ori.size
#      13 cropped_image = image_ori.crop(
#      14     (margin, margin, ori_width - margin, ori_height - margin)
#      15 )
#
# File c:\Users\G6330\AppData\Local\miniconda3\envs\mag2d\Lib\site-packages\PIL\Image.py:982, in Image.convert(self, mode, matrix, dither, palette, colors)
#     979 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     980     deprecate(mode, 12)
# --> 982 self.load()
#     984 has_transparency = "transparency" in self.info
#     985 if not mode and self.mode == "P":
#     986     # determine default mode
#
# File c:\Users\G6330\AppData\Local\miniconda3\envs\mag2d\Lib\site-packages\PIL\ImageFile.py:408, in ImageFile.load(self)
#     404 self.fp = None
#     406 if not self.map and not LOAD_TRUNCATED_IMAGES and err_code < 0:
#     407     # still raised if decoder fails to return anything
# --> 408     raise _get_oserror(err_code, encoder=False)
#     410 return Image.Image.load(self)
#
# OSError: broken data stream when reading image file

# %%
import json
from PIL import Image, ImageDraw, ImageFont
import os

# --- Configuration ---
original_width = 1351
original_height = 1720
margin = 50
page_width = 658
page_height = 842

# Resize scale factors
scale_x = original_width / page_width
scale_y = original_height / page_height


# --- Draw Bounding Boxes ---
def draw_box(draw, bounds, color):
    x1 = bounds["x1"] * scale_x
    y1 = bounds["y1"] * scale_y
    x2 = bounds["x2"] * scale_x
    y2 = bounds["y2"] * scale_y
    draw.rectangle([x1, y1, x2, y2], outline=color, width=2)


# --- Load Image ---
folder_path = os.path.join("dataSources", "2410", "images")
idml_path = "outputs_idml_json"
idml_bboxs_path = "idml_bboxs"
for idml_folder_name in os.listdir(idml_path):
    idml_folder_path = os.path.join(idml_path, idml_folder_name)
    for idml_json_name in os.listdir(idml_folder_path):
        idml_json_path = os.path.join(idml_folder_path, idml_json_name)
        # print(idml_json_path)
        pages_json = None
        if os.path.exists(idml_json_path):
            with open(idml_json_path, "r", encoding="utf-8") as f:
                pages_json = json.load(f)
        if pages_json:
            list_pages = pages_json["pages"]
            for page_obj in list_pages:
                page_name = page_obj["page_name"]
                img_name = f"fg2410_{page_name}.jpg"
                img_path = os.path.join(folder_path, img_name)
                image = Image.open(img_path).convert("RGB")
                draw = ImageDraw.Draw(image)
                for img in page_obj["images"]:
                    draw_box(draw, img["Bounds"], color="red")
                for text in page_obj["texts"]:
                    draw_box(draw, text["Bounds"], color="blue")
                out_img_path = os.path.join(idml_bboxs_path, img_name)
                image.save(out_img_path)
                # print(f'---- out img path ---- {out_img_path}')


# out_path = 'idml_bboxs'
# for file_name in os.listdir(folder_path):
#     img_path = os.path.join(folder_path,file_name)
#     print(img_path)

# def draw_bboxes(image_path,file_name):
#     pass
# image_path = "dataSources/2410/images/fg2410_102.jpg"  # Replace with your actual image path
# out_path = 'idml_bboxs/fg2410_102.jpg'
# # --- IDML Page Data (replace with your actual JSON if needed) ---
# with open("outputs_idml_json/rose/fg2410_102103roseB1n.json", "r", encoding="utf-8") as f:
#     page_obj = json.load(f)
# image = Image.open(image_path).convert("RGB")
# # cropped_image = image.crop((margin, margin, original_width - margin, original_height - margin))
# draw = ImageDraw.Draw(image)


# --- Draw Bounding Boxes ---
# def draw_box(draw,bounds, color):
#     x1 = bounds["x1"] * scale_x
#     y1 = bounds["y1"] * scale_y
#     x2 = bounds["x2"] * scale_x
#     y2 = bounds["y2"] * scale_y
#     draw.rectangle([x1, y1, x2, y2], outline=color, width=3)

# # Draw image boxes (red)
# for img in page_data["images"]:
#     draw_box(img["Bounds"], color="red")

# # Draw text boxes (blue)
# for text in page_data["texts"]:
#     draw_box(text["Bounds"], color="blue")

# # --- Save or Show Result ---
# # output_path = "output_with_boxes.jpg"
# # image.save(out_path)
# image.show()

# %%
import os
import json
from PIL import Image, ImageDraw

# --- Configuration ---
original_width = 1351
original_height = 1720
margin = 50
page_width = 658
page_height = 842

# Resize scale factors
scale_x = original_width / page_width
scale_y = original_height / page_height

# --- Draw Bounding Boxes ---
def draw_box(draw, bounds, color):
    x1 = bounds["x1"] * scale_x
    y1 = bounds["y1"] * scale_y
    x2 = bounds["x2"] * scale_x
    y2 = bounds["y2"] * scale_y
    draw.rectangle([x1, y1, x2, y2], outline=color, width=2)

# --- Load Image ---
folder_path = os.path.join("dataSources", "2410", "images")
idml_path = "outputs_idml_json"
idml_bboxs_path = "idml_bboxs"
os.makedirs(idml_bboxs_path, exist_ok=True)  # Make sure output folder exists

for idml_folder_name in os.listdir(idml_path):
    idml_folder_path = os.path.join(idml_path, idml_folder_name)
    for idml_json_name in os.listdir(idml_folder_path):
        idml_json_path = os.path.join(idml_folder_path, idml_json_name)
        print(f'idml folder : {idml_folder_name}  json file : {idml_json_name}')

        if os.path.exists(idml_json_path):
            with open(idml_json_path, "r", encoding="utf-8") as f:
                pages_json = json.load(f)

        if pages_json:
            list_pages = pages_json["pages"]
            for page_obj in list_pages:
                page_name = page_obj["page_name"]
                img_name = f"fg2410_{page_name}.jpg"
                img_path = os.path.join(folder_path, img_name)
                if not os.path.exists(img_path):
                    print(f"[SKIP] Image not found: {img_path}")
                    continue

                image = Image.open(img_path).convert("RGB")  # ✅ FIXED here
                draw = ImageDraw.Draw(image)

                for img in page_obj.get("images", []):
                    bounds = img.get("Bounds")
                    if bounds:
                        draw_box(draw, bounds, color="red")
                        print(f'drawing bbox for {img_name} ---- {bounds}')
                    else:
                        print(f"[WARN] Missing bounds in {img_name}")

                out_img_path = os.path.join(idml_bboxs_path, img_name)
                image.save(out_img_path)
                print(f"[OK] Saved image with boxes: {out_img_path}")
# Out:
# idml folder : bbre  json file : fg2410_174175BbreA1.json
# [OK] Saved image with boxes: idml_bboxs\fg2410_174.jpg
# drawing bbox for fg2410_175.jpg ---- {'x1': -11.832250648539457, 'y1': -326.5416508343056, 'x2': 1326.1498328989949, 'y2': 913.5217439083151}
# drawing bbox for fg2410_175.jpg ---- {'x1': 46.896158636333666, 'y1': 563.1937959211288, 'x2': 123.89124293846965, 'y2': 678.566492336479}
# drawing bbox for fg2410_175.jpg ---- {'x1': 36.57110927225449, 'y1': 772.1616604518294, 'x2': 65.47613482223358, 'y2': 801.0666860018084}
# [OK] Saved image with boxes: idml_bboxs\fg2410_175.jpg
# idml folder : bbre  json file : fg2410_176177BbreB1.json
# drawing bbox for fg2410_176.jpg ---- {'x1': 491.81102362204683, 'y1': 641.6573167607298, 'x2': 600.0990236220468, 'y2': 707.8973167607298}
# drawing bbox for fg2410_176.jpg ---- {'x1': 590.1343757160338, 'y1': 717.4375720390846, 'x2': 619.0394012660129, 'y2': 746.3425975890636}
# [OK] Saved image with boxes: idml_bboxs\fg2410_176.jpg
# drawing bbox for fg2410_177.jpg ---- {'x1': -20.759983282998064, 'y1': -9.819212598426475, 'x2': 1326.9873848578018, 'y2': 888.8390503257328}
# drawing bbox for fg2410_177.jpg ---- {'x1': 548.3202708661419, 'y1': 610.5767716543075, 'x2': 602.5458708661419, 'y2': 729.0767716543075}
# drawing bbox for fg2410_177.jpg ---- {'x1': 429.6194677559064, 'y1': 615.3022033235986, 'x2': 483.1364377559064, 'y2': 729.8248660881037}
# drawing bbox for fg2410_177.jpg ---- {'x1': 491.387039480315, 'y1': 615.2564623235985, 'x2': 546.093275480315, 'y2': 730.0663723235984}
# drawing bbox for fg2410_177.jpg ---- {'x1': 372.1864033700796, 'y1': 606.7295991503706, 'x2': 427.1836753700796, 'y2': 724.0196996401664}
# drawing bbox for fg2410_177.jpg ---- {'x1': 5.2001452354799085, 'y1': 685.6120078652079, 'x2': 174.76486155450914, 'y2': 820.7902624307105}
# [OK] Saved image with boxes: idml_bboxs\fg2410_177.jpg
# idml folder : bbre  json file : fg2410_178179BbreC1.json
# drawing bbox for fg2410_178.jpg ---- {'x1': -889.7364141732282, 'y1': -52.44733094173267, 'x2': 1094.5835858267717, 'y2': 1081.3126690582674}
# drawing bbox for fg2410_178.jpg ---- {'x1': 128.8655282759055, 'y1': 500.0272022899184, 'x2': 243.8903772359055, 'y2': 584.3534918899184}
# drawing bbox for fg2410_178.jpg ---- {'x1': 68.13016439036424, 'y1': 527.1023622039606, 'x2': 97.13056439036424, 'y2': 556.1027622039607}
# [OK] Saved image with boxes: idml_bboxs\fg2410_178.jpg
# [OK] Saved image with boxes: idml_bboxs\fg2410_179.jpg
# idml folder : bbre  json file : fg2410_180181BbreD1.json
# drawing bbox for fg2410_180.jpg ---- {'x1': 8.643091030224127, 'y1': 284.9640960914435, 'x2': 322.9116282894985, 'y2': 448.17852989175583}
# drawing bbox for fg2410_180.jpg ---- {'x1': 41.932655647632345, 'y1': 284.6806315245144, 'x2': 356.2011929069067, 'y2': 447.89506532482676}
# [OK] Saved image with boxes: idml_bboxs\fg2410_180.jpg
# drawing bbox for fg2410_181.jpg ---- {'x1': -435.52351403520606, 'y1': -17.007874016512005, 'x2': 1548.7964859647939, 'y2': 975.1521259834881}
# drawing bbox for fg2410_181.jpg ---- {'x1': 281.5748031496066, 'y1': 290.6728744334882, 'x2': 423.4873791496067, 'y2': 503.5417384334882}
# drawing bbox for fg2410_181.jpg ---- {'x1': 180.44642516220506, 'y1': 440.5928736967248, 'x2': 324.11577956220503, 'y2': 536.4682228663248}
# [OK] Saved image with boxes: idml_bboxs\fg2410_181.jpg
# idml folder : iryo  json file : fg2410_182185iryo1a.json
# drawing bbox for fg2410_182.jpg ---- {'x1': 0.12528316032899056, 'y1': 585.4156588346455, 'x2': 592.701087389829, 'y2': 823.4780428850456}
# [OK] Saved image with boxes: idml_bboxs\fg2410_182.jpg
# drawing bbox for fg2410_183.jpg ---- {'x1': 64.93670788576196, 'y1': 585.4156588346455, 'x2': 657.512512115262, 'y2': 822.9620117057456}
# drawing bbox for fg2410_183.jpg ---- {'x1': 54.65522557965778, 'y1': 390.5351110409227, 'x2': 383.48606557965775, 'y2': 568.1485035307186}
# drawing bbox for fg2410_183.jpg ---- {'x1': 294.493805384683, 'y1': 349.7692939964229, 'x2': 351.238478079883, 'y2': 425.5142135958821}
# drawing bbox for fg2410_183.jpg ---- {'x1': -116.5518634017468, 'y1': 377.84246510827643, 'x2': 148.9445365982532, 'y2': 521.2466430674601}
# [OK] Saved image with boxes: idml_bboxs\fg2410_183.jpg
# drawing bbox for fg2410_184.jpg ---- {'x1': 223.25935926734834, 'y1': 46.68528529799505, 'x2': 577.4166515815393, 'y2': 372.9096190358796}
# [OK] Saved image with boxes: idml_bboxs\fg2410_184.jpg
# drawing bbox for fg2410_185.jpg ---- {'x1': -8.503937007873787, 'y1': 15.041385826772057, 'x2': 573.6160629921263, 'y2': 825.7853858267722}
# drawing bbox for fg2410_185.jpg ---- {'x1': 304.93177249067423, 'y1': 374.15639936460684, 'x2': 749.9817724906743, 'y2': 670.29643711063}
# drawing bbox for fg2410_185.jpg ---- {'x1': 34.2260787401583, 'y1': 562.8866220487694, 'x2': 196.51407874015825, 'y2': 697.1606220487693}
# drawing bbox for fg2410_185.jpg ---- {'x1': 19.274229921259803, 'y1': 285.4536242257477, 'x2': 129.0091419212598, 'y2': 435.04848237892065}
# drawing bbox for fg2410_185.jpg ---- {'x1': 41.594946519686346, 'y1': 14.765384694108434, 'x2': 155.06233851968642, 'y2': 166.01525923110648}
# [OK] Saved image with boxes: idml_bboxs\fg2410_185.jpg
# idml folder : kot  json file : fg2410_052053kotA1a.json
# [OK] Saved image with boxes: idml_bboxs\fg2410_052.jpg
# drawing bbox for fg2410_053.jpg ---- {'x1': -56.8237073561877, 'y1': -15.073669156939445, 'x2': 1328.7510957934176, 'y2': 929.0098901086193}
# [OK] Saved image with boxes: idml_bboxs\fg2410_053.jpg
# idml folder : kot  json file : fg2410_054061kotB2a.json
# drawing bbox for fg2410_054.jpg ---- {'x1': -666.141732283465, 'y1': -54.35707019404987, 'x2': 759.4015748031495, 'y2': 896.4165467401972}
# [OK] Saved image with boxes: idml_bboxs\fg2410_054.jpg
# [OK] Saved image with boxes: idml_bboxs\fg2410_055.jpg
# drawing bbox for fg2410_056.jpg ---- {'x1': 5.684341886080802e-14, 'y1': -94.67716535203931, 'x2': 666.1417322834645, 'y2': 904.1239804899064}
# [OK] Saved image with boxes: idml_bboxs\fg2410_056.jpg
# drawing bbox for fg2410_057.jpg ---- {'x1': -8.503937007873901, 'y1': -89.00787401345656, 'x2': 657.6377952755906, 'y2': 909.7932718284892}
# [OK] Saved image with boxes: idml_bboxs\fg2410_057.jpg
# drawing bbox for fg2410_058.jpg ---- {'x1': 0.0, 'y1': 185.38582677547174, 'x2': 328.8188976377952, 'y2': 678.3741594382691}
# drawing bbox for fg2410_058.jpg ---- {'x1': 328.8188976377953, 'y1': 159.0203787417454, 'x2': 666.1417322834645, 'y2': 664.8446103902093}
# drawing bbox for fg2410_058.jpg ---- {'x1': 334.4881889763777, 'y1': 680.4035433055597, 'x2': 538.5826771653543, 'y2': 816.4665354315443}
# drawing bbox for fg2410_058.jpg ---- {'x1': 209.76377952755877, 'y1': 680.4035433055592, 'x2': 323.14960629921234, 'y2': 850.4222909621017}
# [OK] Saved image with boxes: idml_bboxs\fg2410_058.jpg
# drawing bbox for fg2410_059.jpg ---- {'x1': 63.77952755905517, 'y1': 34.015748031495605, 'x2': 318.8976377952756, 'y2': 204.17448759638773}
# drawing bbox for fg2410_059.jpg ---- {'x1': 508.11023622047253, 'y1': 663.3484005762016, 'x2': 644.1732283464568, 'y2': 754.0570619935243}
# drawing bbox for fg2410_059.jpg ---- {'x1': 328.8188976377953, 'y1': 180.06270383173978, 'x2': 657.6377952755905, 'y2': 673.0510364945367}
# drawing bbox for fg2410_059.jpg ---- {'x1': -68.88188976377967, 'y1': 351.3567738024144, 'x2': 396.8503937007872, 'y2': 661.9928142973527}
# drawing bbox for fg2410_059.jpg ---- {'x1': -8.503937007874015, 'y1': 211.59635055791068, 'x2': 328.81889763779526, 'y2': 436.47824032169046}
# drawing bbox for fg2410_059.jpg ---- {'x1': 383.38582677165357, 'y1': 680.4035433055601, 'x2': 496.77165354330714, 'y2': 850.422290962103}
# drawing bbox for fg2410_059.jpg ---- {'x1': 167.95275590551194, 'y1': 680.4035433055601, 'x2': 372.0472440944883, 'y2': 816.4665354315443}
# [OK] Saved image with boxes: idml_bboxs\fg2410_059.jpg
# drawing bbox for fg2410_060.jpg ---- {'x1': 48.18897637795271, 'y1': -8.503937007873901, 'x2': 212.59842519685, 'y2': 237.99022932352455}
# drawing bbox for fg2410_060.jpg ---- {'x1': 422.3622047244108, 'y1': 200.40944882424446, 'x2': 637.7952755905525, 'y2': 523.4150490600441}
# drawing bbox for fg2410_060.jpg ---- {'x1': 292.72440945111083, 'y1': 366.23622047778736, 'x2': 411.4015748008583, 'y2': 544.1919699354976}
# drawing bbox for fg2410_060.jpg ---- {'x1': 204.09448818897653, 'y1': 544.251968502409, 'x2': 408.188976377953, 'y2': 850.3216843821374}
# drawing bbox for fg2410_060.jpg ---- {'x1': 91.84251968503975, 'y1': 238.11023622047287, 'x2': 295.9370078740161, 'y2': 544.1799521002013}
# drawing bbox for fg2410_060.jpg ---- {'x1': 408.18897637795294, 'y1': 567.4960629974721, 'x2': 666.1417322834648, 'y2': 739.5445522851487}
# drawing bbox for fg2410_060.jpg ---- {'x1': 5.684341886080802e-14, 'y1': 544.2519685039379, 'x2': 204.09448818897647, 'y2': 680.3149606299221}
# [OK] Saved image with boxes: idml_bboxs\fg2410_060.jpg
# drawing bbox for fg2410_061.jpg ---- {'x1': -8.503937007873901, 'y1': -26.36220471906381, 'x2': 657.6377952755907, 'y2': 972.4389411228831}
# [OK] Saved image with boxes: idml_bboxs\fg2410_061.jpg
# idml folder : kot  json file : fg2410_062065kotC1a.json
# drawing bbox for fg2410_062.jpg ---- {'x1': 0.0, 'y1': -60.94488188976226, 'x2': 666.141732283464, 'y2': 938.2677165354337}
# [OK] Saved image with boxes: idml_bboxs\fg2410_062.jpg
# drawing bbox for fg2410_063.jpg ---- {'x1': -8.503937007872878, 'y1': -117.63779526871627, 'x2': 657.6377952755894, 'y2': 881.5748031564772}
# [OK] Saved image with boxes: idml_bboxs\fg2410_063.jpg
# drawing bbox for fg2410_064.jpg ---- {'x1': 48.18897637795277, 'y1': -8.503937007872992, 'x2': 184.251968503937, 'y2': 195.59055118110314}
# drawing bbox for fg2410_064.jpg ---- {'x1': 328.81889763779554, 'y1': 163.05717088102256, 'x2': 666.1417322834648, 'y2': 669.0414228495265}
# drawing bbox for fg2410_064.jpg ---- {'x1': 2.2737367544323206e-13, 'y1': 183.685039378483, 'x2': 328.81889763779554, 'y2': 676.8233970837698}
# drawing bbox for fg2410_064.jpg ---- {'x1': 256.53543307086613, 'y1': 680.3149606299226, 'x2': 460.62992125984255, 'y2': 816.3779527559063}
# drawing bbox for fg2410_064.jpg ---- {'x1': 131.81102362204723, 'y1': 680.3149606299212, 'x2': 245.1968503937008, 'y2': 850.3337082864641}
# [OK] Saved image with boxes: idml_bboxs\fg2410_064.jpg
# drawing bbox for fg2410_065.jpg ---- {'x1': 59.5275590551189, 'y1': -8.503937007872537, 'x2': 195.59055118110246, 'y2': 195.5905511811029}
# drawing bbox for fg2410_065.jpg ---- {'x1': 328.8188976377953, 'y1': 209.7637795275582, 'x2': 657.6377952755906, 'y2': 702.9021372328452}
# drawing bbox for fg2410_065.jpg ---- {'x1': -28.85961986326413, 'y1': 132.6623753133258, 'x2': 329.0061754123268, 'y2': 669.2810552512215}
# drawing bbox for fg2410_065.jpg ---- {'x1': 291.9685039370078, 'y1': 680.3573003695342, 'x2': 496.0629921259841, 'y2': 816.4202924955202}
# drawing bbox for fg2410_065.jpg ---- {'x1': 167.2440944881891, 'y1': 680.3573003695344, 'x2': 280.6299212598425, 'y2': 850.4960330279523}
# [OK] Saved image with boxes: idml_bboxs\fg2410_065.jpg
# idml folder : kot  json file : fg2410_066069kotD2.json
# drawing bbox for fg2410_066.jpg ---- {'x1': 2.2737367544323206e-13, 'y1': -8.503937007872594, 'x2': 666.1417322834644, 'y2': 990.2972088340728}
# [OK] Saved image with boxes: idml_bboxs\fg2410_066.jpg
# drawing bbox for fg2410_067.jpg ---- {'x1': -8.503937007874129, 'y1': -125.64237566256128, 'x2': 657.6377952755907, 'y2': 873.1587701793849}
# [OK] Saved image with boxes: idml_bboxs\fg2410_067.jpg
# drawing bbox for fg2410_068.jpg ---- {'x1': 328.8188976377954, 'y1': -8.503937007874129, 'x2': 666.1417322834648, 'y2': 497.3202946405893}
# drawing bbox for fg2410_068.jpg ---- {'x1': 0.0, 'y1': -8.503937007873901, 'x2': 328.81889763779543, 'y2': 484.4843956549232}
# drawing bbox for fg2410_068.jpg ---- {'x1': 324.5669291338583, 'y1': 659.1082411534867, 'x2': 466.29921259842524, 'y2': 871.6038127338898}
# drawing bbox for fg2410_068.jpg ---- {'x1': 48.18897637795277, 'y1': 505.70078741303814, 'x2': 218.26771653543307, 'y2': 760.613240164183}
# [OK] Saved image with boxes: idml_bboxs\fg2410_068.jpg
# drawing bbox for fg2410_069.jpg ---- {'x1': 328.8188976377953, 'y1': -8.503937007873901, 'x2': 657.6377952755906, 'y2': 484.484395654923}
# drawing bbox for fg2410_069.jpg ---- {'x1': -8.503937007874015, 'y1': -22.960629909797262, 'x2': 328.8188976377952, 'y2': 482.8636017386659}
# drawing bbox for fg2410_069.jpg ---- {'x1': 42.51968503937019, 'y1': 503.30260066740675, 'x2': 212.59842519685049, 'y2': 758.2150534185516}
# drawing bbox for fg2410_069.jpg ---- {'x1': 347.24409448818903, 'y1': 637.901521678577, 'x2': 488.976377952756, 'y2': 850.39709325898}
# [OK] Saved image with boxes: idml_bboxs\fg2410_069.jpg
# idml folder : kot  json file : fg2410_070071kotE1c.json
# drawing bbox for fg2410_070.jpg ---- {'x1': -52.44094488188961, 'y1': -82.331271091877, 'x2': 712.9133858267719, 'y2': 924.2210348698779}
# drawing bbox for fg2410_070.jpg ---- {'x1': 40.18310362204727, 'y1': 267.9747049809287, 'x2': 621.1380302362207, 'y2': 581.8182639816422}
# drawing bbox for fg2410_070.jpg ---- {'x1': 393.732283464567, 'y1': 614.9263693551429, 'x2': 628.3856692913387, 'y2': 799.3700787386317}
# drawing bbox for fg2410_070.jpg ---- {'x1': -3.889711497889607, 'y1': 559.686795685351, 'x2': 330.187581415496, 'y2': 793.2529030584162}
# [OK] Saved image with boxes: idml_bboxs\fg2410_070.jpg
# drawing bbox for fg2410_071.jpg ---- {'x1': -60.94488188976379, 'y1': -82.331271091877, 'x2': 704.4094488188977, 'y2': 924.2210348698779}
# drawing bbox for fg2410_071.jpg ---- {'x1': 337.4950558495598, 'y1': 405.2386293923311, 'x2': 695.5347608889299, 'y2': 689.2508169778653}
# drawing bbox for fg2410_071.jpg ---- {'x1': 10.305925016812807, 'y1': 201.59066727669838, 'x2': 300.9871970535115, 'y2': 429.6045172233495}
# drawing bbox for fg2410_071.jpg ---- {'x1': 439.3700787401575, 'y1': 222.37795276889878, 'x2': 609.4488188976378, 'y2': 451.196850406694}
# drawing bbox for fg2410_071.jpg ---- {'x1': 119.22544361721111, 'y1': 379.84891969749054, 'x2': 320.9229475542237, 'y2': 682.3231921968936}
# drawing bbox for fg2410_071.jpg ---- {'x1': 522.5246993190888, 'y1': 667.6691922656107, 'x2': 614.5511811023623, 'y2': 783.7795275590552}
# drawing bbox for fg2410_071.jpg ---- {'x1': 394.73043326074105, 'y1': 669.2598425189212, 'x2': 535.0996084262807, 'y2': 780.9448818897638}
# drawing bbox for fg2410_071.jpg ---- {'x1': 307.02934860415183, 'y1': 671.8110236220477, 'x2': 402.5196850393702, 'y2': 779.537558947206}
# drawing bbox for fg2410_071.jpg ---- {'x1': 189.6934682519185, 'y1': 671.811023622048, 'x2': 298.5254115962779, 'y2': 779.5275590551182}
# [OK] Saved image with boxes: idml_bboxs\fg2410_071.jpg
# idml folder : kot  json file : fg2410_072075kotF1a.json
# drawing bbox for fg2410_072.jpg ---- {'x1': 32.26567931575289, 'y1': 26.08852746226671, 'x2': 500.6477065110187, 'y2': 808.4507321866762}
# [OK] Saved image with boxes: idml_bboxs\fg2410_072.jpg
# drawing bbox for fg2410_073.jpg ---- {'x1': 29.72819492735232, 'y1': 34.015748031496, 'x2': 617.2121074401789, 'y2': 808.4507321866763}
# [OK] Saved image with boxes: idml_bboxs\fg2410_073.jpg
# drawing bbox for fg2410_074.jpg ---- {'x1': 44.519436324487174, 'y1': 28.346456692912852, 'x2': 628.462788202836, 'y2': 805.3866141724689}
# [OK] Saved image with boxes: idml_bboxs\fg2410_074.jpg
# drawing bbox for fg2410_075.jpg ---- {'x1': -60.94488188976379, 'y1': -82.33127109187694, 'x2': 704.4094488188977, 'y2': 924.2210348698777}
# drawing bbox for fg2410_075.jpg ---- {'x1': 48.036165290658914, 'y1': 220.89879698610002, 'x2': 388.4992677802071, 'y2': 447.9251585473837}
# drawing bbox for fg2410_075.jpg ---- {'x1': 34.01574803149606, 'y1': 536.5984252129017, 'x2': 257.95275590551194, 'y2': 685.8897637955788}
# drawing bbox for fg2410_075.jpg ---- {'x1': 399.6850393700788, 'y1': 220.89879698610434, 'x2': 550.7304315865387, 'y2': 447.4068990549497}
# drawing bbox for fg2410_075.jpg ---- {'x1': 213.9126005475748, 'y1': 697.1192694270487, 'x2': 443.7251947280158, 'y2': 850.367667739541}
# drawing bbox for fg2410_075.jpg ---- {'x1': 269.29133858267767, 'y1': 459.00903320657517, 'x2': 609.4488188976383, 'y2': 685.6777490950735}
# [OK] Saved image with boxes: idml_bboxs\fg2410_075.jpg
# idml folder : kot  json file : fg2410_076079kotG1b.json
# drawing bbox for fg2410_076.jpg ---- {'x1': 1.1368683772161603e-13, 'y1': -8.5039370078768, 'x2': 666.1417322834645, 'y2': 939.071362219312}
# [OK] Saved image with boxes: idml_bboxs\fg2410_076.jpg
# drawing bbox for fg2410_077.jpg ---- {'x1': -8.503937007874015, 'y1': -82.23931120912567, 'x2': 657.6377952755909, 'y2': 850.5236950210256}
# [OK] Saved image with boxes: idml_bboxs\fg2410_077.jpg
# drawing bbox for fg2410_078.jpg ---- {'x1': -0.9835427679367967, 'y1': -142.79512698970507, 'x2': 705.8634462084411, 'y2': 873.0402721853106}
# [OK] Saved image with boxes: idml_bboxs\fg2410_078.jpg
# drawing bbox for fg2410_079.jpg ---- {'x1': 34.01574803149606, 'y1': 28.346456692911033, 'x2': 609.4488188976376, 'y2': 412.037081349813}
# drawing bbox for fg2410_079.jpg ---- {'x1': 33.983959661655035, 'y1': 422.36220472440846, 'x2': 609.4806072674788, 'y2': 805.9580759841874}
# [OK] Saved image with boxes: idml_bboxs\fg2410_079.jpg
# idml folder : kot  json file : fg2410_080081kotH1b.json
# drawing bbox for fg2410_080.jpg ---- {'x1': -52.44094488188961, 'y1': -82.33127109188064, 'x2': 712.9133858267719, 'y2': 924.2210348698743}
# drawing bbox for fg2410_080.jpg ---- {'x1': 239.63185947910355, 'y1': 237.7559055118159, 'x2': 435.1555420956996, 'y2': 368.14960629921757}
# drawing bbox for fg2410_080.jpg ---- {'x1': 340.36447704569383, 'y1': 367.04574468997095, 'x2': 428.09313623532995, 'y2': 498.5787275515868}
# drawing bbox for fg2410_080.jpg ---- {'x1': 252.69943544792835, 'y1': 368.1496062992175, 'x2': 340.36447704569383, 'y2': 499.5872062871121}
# drawing bbox for fg2410_080.jpg ---- {'x1': 252.69943544792835, 'y1': 550.0157480521273, 'x2': 428.09313623532984, 'y2': 666.9848713542589}
# drawing bbox for fg2410_080.jpg ---- {'x1': 48.188976377952756, 'y1': 237.7559055118171, 'x2': 135.90168944881896, 'y2': 369.26498010233604}
# drawing bbox for fg2410_080.jpg ---- {'x1': 135.90168944881887, 'y1': 236.46232548931883, 'x2': 223.61440251968503, 'y2': 367.9714000798377}
# drawing bbox for fg2410_080.jpg ---- {'x1': 135.9016894488189, 'y1': 366.8560262767203, 'x2': 223.61440251968506, 'y2': 498.3651008672392}
# drawing bbox for fg2410_080.jpg ---- {'x1': 48.188976377952756, 'y1': 366.85602627672154, 'x2': 135.90168944881896, 'y2': 498.36510086724047}
# drawing bbox for fg2410_080.jpg ---- {'x1': 48.18897637795277, 'y1': 550.0157480521304, 'x2': 223.58267716535434, 'y2': 666.8649030226702}
# [OK] Saved image with boxes: idml_bboxs\fg2410_080.jpg
# drawing bbox for fg2410_081.jpg ---- {'x1': -63.779527559055055, 'y1': -82.331271091877, 'x2': 701.5748031496064, 'y2': 924.2210348698779}
# drawing bbox for fg2410_081.jpg ---- {'x1': -51.02362204724432, 'y1': -82.33127109188064, 'x2': 714.3307086614171, 'y2': 924.2210348698743}
# drawing bbox for fg2410_081.jpg ---- {'x1': 418.39370078740166, 'y1': 237.75590551181608, 'x2': 613.9173834039977, 'y2': 368.1496062992177}
# drawing bbox for fg2410_081.jpg ---- {'x1': 434.0551181102363, 'y1': 368.14960629921745, 'x2': 521.7193700787402, 'y2': 499.46609864601885}
# drawing bbox for fg2410_081.jpg ---- {'x1': 521.7845669291339, 'y1': 368.14960629921745, 'x2': 609.4488188976379, 'y2': 499.46609864601885}
# drawing bbox for fg2410_081.jpg ---- {'x1': 416.1259842519686, 'y1': 532.886815083592, 'x2': 617.3858267716536, 'y2': 667.1059303070481}
# drawing bbox for fg2410_081.jpg ---- {'x1': 226.85823743185915, 'y1': 237.75590551181622, 'x2': 422.3819200484553, 'y2': 368.1496062992179}
# drawing bbox for fg2410_081.jpg ---- {'x1': 236.92322834645648, 'y1': 550.0157480521284, 'x2': 412.31692913385797, 'y2': 666.98487135426}
# drawing bbox for fg2410_081.jpg ---- {'x1': 39.68503937007881, 'y1': 237.7559055118159, 'x2': 127.38188976377967, 'y2': 369.481133599755}
# drawing bbox for fg2410_081.jpg ---- {'x1': 127.332046312373, 'y1': 237.7559055118159, 'x2': 215.12858360888652, 'y2': 369.63086850986224}
# drawing bbox for fg2410_081.jpg ---- {'x1': 127.332046312373, 'y1': 368.1496062992175, 'x2': 215.12858360888652, 'y2': 500.02456929726384}
# drawing bbox for fg2410_081.jpg ---- {'x1': 39.68503937007881, 'y1': 368.14960629921745, 'x2': 127.38188976377967, 'y2': 499.8748343871566}
# drawing bbox for fg2410_081.jpg ---- {'x1': 39.68503937007881, 'y1': 550.0157480521286, 'x2': 215.0787401574803, 'y2': 666.7449346910764}
# drawing bbox for fg2410_081.jpg ---- {'x1': 169.23522103436676, 'y1': 368.1496062992175, 'x2': 366.54089881536174, 'y2': 499.80674043896903}
# drawing bbox for fg2410_081.jpg ---- {'x1': 324.5915703432576, 'y1': 368.14960629921745, 'x2': 412.3780359559545, 'y2': 499.7093778526716}
# [OK] Saved image with boxes: idml_bboxs\fg2410_081.jpg
# idml folder : kot  json file : fg2410_082085kotI1a.json
# drawing bbox for fg2410_082.jpg ---- {'x1': 15.681037094782567, 'y1': 112.58206841391228, 'x2': 331.59985440668777, 'y2': 574.5905122284325}
# drawing bbox for fg2410_082.jpg ---- {'x1': 345.5828805190897, 'y1': 548.1271141290113, 'x2': 695.8636629302579, 'y2': 782.0463293099326}
# drawing bbox for fg2410_082.jpg ---- {'x1': -15.182555301510561, 'y1': 472.3846417091962, 'x2': 219.68019214106232, 'y2': 813.6511571687628}
# drawing bbox for fg2410_082.jpg ---- {'x1': 86.5769638056878, 'y1': 595.8326962332658, 'x2': 499.1681612452183, 'y2': 869.4117762201042}
# [OK] Saved image with boxes: idml_bboxs\fg2410_082.jpg
# drawing bbox for fg2410_083.jpg ---- {'x1': 232.79483953047622, 'y1': 200.53286477507055, 'x2': 717.7353176593435, 'y2': 522.8004383753578}
# drawing bbox for fg2410_083.jpg ---- {'x1': -50.25779459363059, 'y1': 512.4662329473165, 'x2': 387.23583324829394, 'y2': 802.6274478836517}
# [OK] Saved image with boxes: idml_bboxs\fg2410_083.jpg
# drawing bbox for fg2410_084.jpg ---- {'x1': 66.21022018496774, 'y1': 371.9465497464305, 'x2': 418.4641379069897, 'y2': 607.41408301098}
# drawing bbox for fg2410_084.jpg ---- {'x1': -27.3656315617755, 'y1': 190.7673011691511, 'x2': 321.8491185343677, 'y2': 423.4634023568108}
# drawing bbox for fg2410_084.jpg ---- {'x1': 315.2673096158679, 'y1': 406.61536047306004, 'x2': 649.948192830823, 'y2': 900.8193215999609}
# drawing bbox for fg2410_084.jpg ---- {'x1': 330.48177612972165, 'y1': 1.569153995289298, 'x2': 543.5647163662458, 'y2': 142.2326895433191}
# drawing bbox for fg2410_084.jpg ---- {'x1': 478.01700556875335, 'y1': 16.1065399626209, 'x2': 662.2259969666245, 'y2': 138.2404138526872}
# drawing bbox for fg2410_084.jpg ---- {'x1': 382.0580113285337, 'y1': 126.58866112587998, 'x2': 589.1690511684931, 'y2': 263.84653384318267}
# [OK] Saved image with boxes: idml_bboxs\fg2410_084.jpg
# drawing bbox for fg2410_085.jpg ---- {'x1': 44.02985782112296, 'y1': -97.30197053508255, 'x2': 393.6799574169229, 'y2': 415.5181755387571}
# drawing bbox for fg2410_085.jpg ---- {'x1': 242.04357945226246, 'y1': 240.56961360795776, 'x2': 477.4095110254117, 'y2': 584.9327927981949}
# drawing bbox for fg2410_085.jpg ---- {'x1': 386.5692667711087, 'y1': 221.71442468156783, 'x2': 603.5146322838028, 'y2': 540.8442014864731}
# drawing bbox for fg2410_085.jpg ---- {'x1': 2.22780359323383, 'y1': 524.7711823987956, 'x2': 415.3112735839934, 'y2': 798.6788524757981}
# [OK] Saved image with boxes: idml_bboxs\fg2410_085.jpg
# idml folder : kot  json file : fg2410_086091kotJ2a.json
# drawing bbox for fg2410_086.jpg ---- {'x1': 5.684341886080802e-14, 'y1': -8.503937007874185, 'x2': 666.141732283465, 'y2': 990.2972088340719}
# [OK] Saved image with boxes: idml_bboxs\fg2410_086.jpg
# drawing bbox for fg2410_087.jpg ---- {'x1': 150.23622047244123, 'y1': 632.0149023446762, 'x2': 379.84251968503963, 'y2': 785.2778272895976}
# drawing bbox for fg2410_087.jpg ---- {'x1': 507.40157480314986, 'y1': 606.6141732283493, 'x2': 609.448818897638, 'y2': 759.6850393700815}
# drawing bbox for fg2410_087.jpg ---- {'x1': 65.80688884749406, 'y1': 7.615375036717694, 'x2': 342.80975961485984, 'y2': 192.35252910214246}
# drawing bbox for fg2410_087.jpg ---- {'x1': -1.919316100941728, 'y1': -15.050778254888655, 'x2': 185.7144373367032, 'y2': 110.14126008590847}
# drawing bbox for fg2410_087.jpg ---- {'x1': 5.921759075497221, 'y1': 79.75600349948616, 'x2': 174.79213716937772, 'y2': 192.37053700301792}
# drawing bbox for fg2410_087.jpg ---- {'x1': 39.685039370078925, 'y1': 631.559055144867, 'x2': 141.0236220472442, 'y2': 699.1524041995854}
# drawing bbox for fg2410_087.jpg ---- {'x1': 34.01574803149606, 'y1': 212.59842519684838, 'x2': 609.448818897638, 'y2': 596.3404668254424}
# [OK] Saved image with boxes: idml_bboxs\fg2410_087.jpg
# drawing bbox for fg2410_088.jpg ---- {'x1': 0.0, 'y1': -8.503937007876402, 'x2': 378.22703221603825, 'y2': 558.5166222872333}
# drawing bbox for fg2410_088.jpg ---- {'x1': 388.3464566929134, 'y1': 514.8509193970478, 'x2': 666.1417322834648, 'y2': 700.1917797832784}
# drawing bbox for fg2410_088.jpg ---- {'x1': 521.5748031496063, 'y1': 344.46494949476005, 'x2': 623.6220472440945, 'y2': 497.43294543075194}
# drawing bbox for fg2410_088.jpg ---- {'x1': 182.33175269330252, 'y1': 512.8474747034838, 'x2': 431.6084951662329, 'y2': 679.1348066254016}
# drawing bbox for fg2410_088.jpg ---- {'x1': 138.294537673648, 'y1': 622.0902783194035, 'x2': 353.54180207566947, 'y2': 765.657015588979}
# drawing bbox for fg2410_088.jpg ---- {'x1': 260.18676561833087, 'y1': 689.3858957324294, 'x2': 443.3662456964181, 'y2': 811.5741171433042}
# drawing bbox for fg2410_088.jpg ---- {'x1': 48.18897637795308, 'y1': 640.3464567196686, 'x2': 149.52755905511842, 'y2': 707.939805774387}
# [OK] Saved image with boxes: idml_bboxs\fg2410_088.jpg
# drawing bbox for fg2410_089.jpg ---- {'x1': -9.59932279909708, 'y1': -8.503937007874356, 'x2': 369.5993227990971, 'y2': 560.2043014685464}
# drawing bbox for fg2410_089.jpg ---- {'x1': 379.84251968503946, 'y1': 514.8509193970494, 'x2': 657.6377952755906, 'y2': 699.9880288712684}
# drawing bbox for fg2410_089.jpg ---- {'x1': 507.40157480314974, 'y1': 344.3878469459744, 'x2': 609.4488188976379, 'y2': 497.56158329344703}
# drawing bbox for fg2410_089.jpg ---- {'x1': 258.1422903959825, 'y1': 671.1671273797524, 'x2': 497.0462274038564, 'y2': 830.3850415275806}
# drawing bbox for fg2410_089.jpg ---- {'x1': 166.49357063138757, 'y1': 529.9083398630396, 'x2': 436.11372811170247, 'y2': 709.5971286870172}
# drawing bbox for fg2410_089.jpg ---- {'x1': 99.65224864539209, 'y1': 647.2471233484368, 'x2': 341.400280141455, 'y2': 808.3604888551677}
# drawing bbox for fg2410_089.jpg ---- {'x1': 34.01574803149583, 'y1': 630.7086614188504, 'x2': 135.35433070866122, 'y2': 698.3020104735688}
# [OK] Saved image with boxes: idml_bboxs\fg2410_089.jpg
# drawing bbox for fg2410_090.jpg ---- {'x1': 360.5039370099126, 'y1': 387.685039372373, 'x2': 668.9763779527561, 'y2': 850.3937007866384}
# drawing bbox for fg2410_090.jpg ---- {'x1': 36.623365676134455, 'y1': 541.154618775628, 'x2': 148.85230003172688, 'y2': 709.558035781934}
# drawing bbox for fg2410_090.jpg ---- {'x1': 99.59378421618024, 'y1': 534.8546924436646, 'x2': 219.25299178510465, 'y2': 714.4035134297337}
# drawing bbox for fg2410_090.jpg ---- {'x1': 158.6721865115458, 'y1': 525.1059535402533, 'x2': 284.8786479490894, 'y2': 714.4767330447958}
# drawing bbox for fg2410_090.jpg ---- {'x1': 266.45669291338584, 'y1': 602.4566929416715, 'x2': 368.50393700787396, 'y2': 755.6476146646914}
# drawing bbox for fg2410_090.jpg ---- {'x1': 42.519685039370074, 'y1': 741.6832565732934, 'x2': 143.85826771653547, 'y2': 809.2823348283218}
# drawing bbox for fg2410_090.jpg ---- {'x1': 0.0, 'y1': -8.503937007879358, 'x2': 286.2184283957185, 'y2': 420.823705585698}
# drawing bbox for fg2410_090.jpg ---- {'x1': 339.7671371022381, 'y1': 200.28109468031698, 'x2': 448.2740937537616, 'y2': 363.16155947690686}
# drawing bbox for fg2410_090.jpg ---- {'x1': 292.01920957607285, 'y1': 153.89769919176797, 'x2': 392.55785100573627, 'y2': 304.7056613362629}
# drawing bbox for fg2410_090.jpg ---- {'x1': 415.1795314943036, 'y1': 183.80600868709416, 'x2': 526.220753840063, 'y2': 350.4278644880824}
# drawing bbox for fg2410_090.jpg ---- {'x1': 521.5748031496062, 'y1': 213.16535435898868, 'x2': 623.6220472440946, 'y2': 366.3562760820091}
# drawing bbox for fg2410_090.jpg ---- {'x1': 297.5570110728838, 'y1': 343.55905514639517, 'x2': 398.8955937500492, 'y2': 411.1581334014236}
# [OK] Saved image with boxes: idml_bboxs\fg2410_090.jpg
# drawing bbox for fg2410_091.jpg ---- {'x1': -8.503937007874015, 'y1': -8.503936999637972, 'x2': 277.85269463041885, 'y2': 420.67108507866806}
# drawing bbox for fg2410_091.jpg ---- {'x1': 366.52055723989224, 'y1': 130.8177277968898, 'x2': 478.6291785262839, 'y2': 298.8778077803431}
# drawing bbox for fg2410_091.jpg ---- {'x1': 408.3441687211258, 'y1': 206.86113573703778, 'x2': 516.5912708298752, 'y2': 369.231788900162}
# drawing bbox for fg2410_091.jpg ---- {'x1': 286.29921259842524, 'y1': 141.73228346456926, 'x2': 371.4002948470307, 'y2': 269.3324551553442}
# drawing bbox for fg2410_091.jpg ---- {'x1': 289.1912773075842, 'y1': 343.5590551463979, 'x2': 390.5298599847495, 'y2': 411.1524042011165}
# drawing bbox for fg2410_091.jpg ---- {'x1': 371.1308183719416, 'y1': 420.94488188899504, 'x2': 657.6377952755906, 'y2': 850.4174005340124}
# drawing bbox for fg2410_091.jpg ---- {'x1': 8.73862193173295, 'y1': 573.0236964318256, 'x2': 125.50464469791325, 'y2': 748.2241693576452}
# drawing bbox for fg2410_091.jpg ---- {'x1': 89.76486026284772, 'y1': 524.8054028891547, 'x2': 215.2613053439066, 'y2': 713.0500705107429}
# drawing bbox for fg2410_091.jpg ---- {'x1': 257.74499160028813, 'y1': 602.4566929416628, 'x2': 359.7922356947763, 'y2': 755.4246888776547}
# drawing bbox for fg2410_091.jpg ---- {'x1': 34.01574803149606, 'y1': 741.6832565732925, 'x2': 135.35433070866145, 'y2': 809.2766056280111}
# drawing bbox for fg2410_091.jpg ---- {'x1': 513.0708661417324, 'y1': 215.00965681177513, 'x2': 615.1181102362206, 'y2': 368.0058177967762}
# [OK] Saved image with boxes: idml_bboxs\fg2410_091.jpg
# idml folder : rose  json file : fg2410_096101roseA1a.json
# drawing bbox for fg2410_096.jpg ---- {'x1': 205.83195185392537, 'y1': 291.85390472266835, 'x2': 544.3452399225719, 'y2': 799.443776566027}
# [OK] Saved image with boxes: idml_bboxs\fg2410_096.jpg
# drawing bbox for fg2410_097.jpg ---- {'x1': -8.503937007874015, 'y1': -146.7738930413472, 'x2': 657.6377952755906, 'y2': 852.0272528005987}
# [OK] Saved image with boxes: idml_bboxs\fg2410_097.jpg
# drawing bbox for fg2410_098.jpg ---- {'x1': 434.6309494616703, 'y1': 501.1878381460449, 'x2': 624.0649606298377, 'y2': 785.1588985862302}
# drawing bbox for fg2410_098.jpg ---- {'x1': 494.23355242020045, 'y1': 45.06929459542948, 'x2': 623.6047749405404, 'y2': 239.0061179654383}
# drawing bbox for fg2410_098.jpg ---- {'x1': 434.6309494616703, 'y1': 257.6160145459685, 'x2': 624.0649606298377, 'y2': 541.6469843963389}
# [OK] Saved image with boxes: idml_bboxs\fg2410_098.jpg
# drawing bbox for fg2410_099.jpg ---- {'x1': -8.503937007873787, 'y1': 207.47548557450386, 'x2': 958.1102362204726, 'y2': 852.1592095365465}
# [OK] Saved image with boxes: idml_bboxs\fg2410_099.jpg
# drawing bbox for fg2410_100.jpg ---- {'x1': 56.692913385826614, 'y1': 382.8040385175118, 'x2': 621.7318951737828, 'y2': 759.7367011055908}
# drawing bbox for fg2410_100.jpg ---- {'x1': 56.69291338582656, 'y1': -8.503937007872992, 'x2': 286.29921259842496, 'y2': 337.26554912343363}
# [OK] Saved image with boxes: idml_bboxs\fg2410_100.jpg
# drawing bbox for fg2410_101.jpg ---- {'x1': -8.503937007873901, 'y1': -124.72440944881828, 'x2': 657.6377952755906, 'y2': 874.0767363931277}
# [OK] Saved image with boxes: idml_bboxs\fg2410_101.jpg
# idml folder : rose  json file : fg2410_102103roseB1n.json
# drawing bbox for fg2410_102.jpg ---- {'x1': 51.558771857318504, 'y1': 58.03210607069383, 'x2': 440.2551741948524, 'y2': 578.6076449156053}
# [OK] Saved image with boxes: idml_bboxs\fg2410_102.jpg
# drawing bbox for fg2410_103.jpg ---- {'x1': 51.37561332568407, 'y1': 246.00555124221586, 'x2': 416.36268537353493, 'y2': 791.1159186794484}
# [OK] Saved image with boxes: idml_bboxs\fg2410_103.jpg
# idml folder : rose  json file : fg2410_104107roseC1.json
# drawing bbox for fg2410_104.jpg ---- {'x1': 170.07874015748038, 'y1': 216.85039369926096, 'x2': 558.4251968503937, 'y2': 799.1643867594505}
# [OK] Saved image with boxes: idml_bboxs\fg2410_104.jpg
# drawing bbox for fg2410_105.jpg ---- {'x1': -8.503937007873674, 'y1': -24.09448818897647, 'x2': 657.6377952755909, 'y2': 975.1181102362204}
# [OK] Saved image with boxes: idml_bboxs\fg2410_105.jpg
# drawing bbox for fg2410_106.jpg ---- {'x1': 431.22883197097264, 'y1': 616.9459881472249, 'x2': 615.1181102362207, 'y2': 739.5388403240568}
# drawing bbox for fg2410_106.jpg ---- {'x1': 104.02503701769676, 'y1': 228.53354645513036, 'x2': 666.1417322834646, 'y2': 603.4836874977557}
# drawing bbox for fg2410_106.jpg ---- {'x1': 466.5890495376934, 'y1': -44.220472440942785, 'x2': 616.8309195988945, 'y2': 181.07030874383054}
# drawing bbox for fg2410_106.jpg ---- {'x1': 56.69291338582673, 'y1': 610.1136644380592, 'x2': 218.2677165354331, 'y2': 852.4758691624688}
# drawing bbox for fg2410_106.jpg ---- {'x1': 235.81219523384493, 'y1': 600.4401156472245, 'x2': 409.6062992125985, 'y2': 861.0592773717844}
# [OK] Saved image with boxes: idml_bboxs\fg2410_106.jpg
# drawing bbox for fg2410_107.jpg ---- {'x1': -8.503937007874129, 'y1': -130.39370078740035, 'x2': 657.6377952755906, 'y2': 869.0246239294224}
# [OK] Saved image with boxes: idml_bboxs\fg2410_107.jpg
# idml folder : rose  json file : fg2410_108111roseD1a.json
# drawing bbox for fg2410_108.jpg ---- {'x1': 406.4173228346458, 'y1': 303.9655194981031, 'x2': 685.9842519685039, 'y2': 490.3434722540085}
# [OK] Saved image with boxes: idml_bboxs\fg2410_108.jpg
# drawing bbox for fg2410_109.jpg ---- {'x1': -226.49797248197888, 'y1': -31.74803148765733, 'x2': 1096.3140166062371, 'y2': 850.195202916881}
# [OK] Saved image with boxes: idml_bboxs\fg2410_109.jpg
# drawing bbox for fg2410_110.jpg ---- {'x1': 513.0708661417325, 'y1': 593.7658882776104, 'x2': 667.0309192365994, 'y2': 696.4859237017772}
# drawing bbox for fg2410_110.jpg ---- {'x1': 514.250533394754, 'y1': 273.7020874456284, 'x2': 616.9780924498721, 'y2': 427.7934260283055}
# drawing bbox for fg2410_110.jpg ---- {'x1': 96.3779527559056, 'y1': 216.44781721937147, 'x2': 488.96608871499694, 'y2': 805.5357801391192}
# [OK] Saved image with boxes: idml_bboxs\fg2410_110.jpg
# drawing bbox for fg2410_111.jpg ---- {'x1': 240.8379647923095, 'y1': 263.6220472440948, 'x2': 467.4171360372907, 'y2': 572.0953031106123}
# drawing bbox for fg2410_111.jpg ---- {'x1': -8.626839121688704, 'y1': 381.4215044376508, 'x2': 116.88170049577673, 'y2': 569.684313863849}
# drawing bbox for fg2410_111.jpg ---- {'x1': 110.5511811023622, 'y1': 455.80040330712336, 'x2': 221.1023622047244, 'y2': 621.6813136389735}
# drawing bbox for fg2410_111.jpg ---- {'x1': 484.3452246760582, 'y1': -15.448818896872353, 'x2': 657.6377952755907, 'y2': 244.4208859367443}
# [OK] Saved image with boxes: idml_bboxs\fg2410_111.jpg
# idml folder : rose  json file : fg2410_112115roseE1a.json
# drawing bbox for fg2410_112.jpg ---- {'x1': 423.2692913385826, 'y1': 308.83911822843675, 'x2': 680.7140787401577, 'y2': 480.4689764961534}
# [OK] Saved image with boxes: idml_bboxs\fg2410_112.jpg
# drawing bbox for fg2410_113.jpg ---- {'x1': -194.49183634055817, 'y1': -8.503937007876175, 'x2': 1093.464566929197, 'y2': 850.1336651719606}
# [OK] Saved image with boxes: idml_bboxs\fg2410_113.jpg
# drawing bbox for fg2410_114.jpg ---- {'x1': -288.1889763779527, 'y1': -17.529476276736432, 'x2': 423.30708661417316, 'y2': 456.8012323846806}
# drawing bbox for fg2410_114.jpg ---- {'x1': 422.12869458020293, 'y1': 483.307086612645, 'x2': 623.3885370998879, 'y2': 785.0528877008137}
# drawing bbox for fg2410_114.jpg ---- {'x1': 71.67741759992622, 'y1': 674.6952757032586, 'x2': 273.5715119179079, 'y2': 809.3713600223878}
# drawing bbox for fg2410_114.jpg ---- {'x1': 289.1338582677168, 'y1': -63.07086614173386, 'x2': 666.1417322834648, 'y2': 502.44094488188784}
# [OK] Saved image with boxes: idml_bboxs\fg2410_114.jpg
# drawing bbox for fg2410_115.jpg ---- {'x1': 482.5984251968504, 'y1': 608.4119914093235, 'x2': 661.0958225524876, 'y2': 876.2181067424954}
# drawing bbox for fg2410_115.jpg ---- {'x1': -8.503937007873901, 'y1': -63.68246474703733, 'x2': 368.503937007874, 'y2': 501.7265072493026}
# drawing bbox for fg2410_115.jpg ---- {'x1': 33.07272614545195, 'y1': 489.9422906708039, 'x2': 234.33256866513693, 'y2': 791.6880917589729}
# [OK] Saved image with boxes: idml_bboxs\fg2410_115.jpg
# idml folder : uranai  json file : fg2410_214215uranai1.json
# drawing bbox for fg2410_214.jpg ---- {'x1': 433.5236220472437, 'y1': 492.5625095253052, 'x2': 605.01968503937, 'y2': 735.0939788059312}
# drawing bbox for fg2410_214.jpg ---- {'x1': -27.664249472096174, 'y1': 479.60972411244086, 'x2': 112.6223188932581, 'y2': 678.0044099866493}
# drawing bbox for fg2410_214.jpg ---- {'x1': 425.48066929133864, 'y1': -51.60982086693042, 'x2': 594.0457086614176, 'y2': 186.77656512053588}
# drawing bbox for fg2410_214.jpg ---- {'x1': -10.038746280320652, 'y1': -75.49728751597127, 'x2': 122.71446938256358, 'y2': 112.24365466487257}
# drawing bbox for fg2410_214.jpg ---- {'x1': 225.8149606299212, 'y1': 452.5790894092286, 'x2': 371.9763779527561, 'y2': 659.2820461824895}
# drawing bbox for fg2410_214.jpg ---- {'x1': 211.2569142519684, 'y1': -69.80776570971284, 'x2': 339.8740157480315, 'y2': 112.08384192379742}
# drawing bbox for fg2410_214.jpg ---- {'x1': 496.30588724150005, 'y1': 506.5331238068938, 'x2': 676.3125112415, 'y2': 761.1115878068938}
# drawing bbox for fg2410_214.jpg ---- {'x1': 10.916100474197492, 'y1': 460.57304320740747, 'x2': 216.83617805419752, 'y2': 751.8001985874075}
# drawing bbox for fg2410_214.jpg ---- {'x1': 537.9730850359472, 'y1': -77.07871666079268, 'x2': 775.4818250359472, 'y2': 258.82342333920724}
# drawing bbox for fg2410_214.jpg ---- {'x1': 377.89864048446594, 'y1': 468.9797032611598, 'x2': 549.8761531691093, 'y2': 712.2028138828946}
# [OK] Saved image with boxes: idml_bboxs\fg2410_214.jpg
# drawing bbox for fg2410_215.jpg ---- {'x1': 464.8325498917314, 'y1': 308.1263544141063, 'x2': 649.6854692551323, 'y2': 535.5048604901401}
# drawing bbox for fg2410_215.jpg ---- {'x1': 180.34565660989125, 'y1': 374.45669291262203, 'x2': 325.21529850055464, 'y2': 579.3328077859637}
# drawing bbox for fg2410_215.jpg ---- {'x1': 23.107523962906043, 'y1': 334.1689582619475, 'x2': 200.97268144322084, 'y2': 585.7076654771168}
# drawing bbox for fg2410_215.jpg ---- {'x1': 358.67805377884656, 'y1': 492.944881889, 'x2': 513.0552787467382, 'y2': 711.2667170476736}
# drawing bbox for fg2410_215.jpg ---- {'x1': 412.04160971078267, 'y1': -31.464566929897785, 'x2': 572.5871037433999, 'y2': 195.58049681539848}
# drawing bbox for fg2410_215.jpg ---- {'x1': 229.17784251968482, 'y1': -81.4304763795621, 'x2': 357.1918582677165, 'y2': 99.60824128073068}
# drawing bbox for fg2410_215.jpg ---- {'x1': -78.92392824561944, 'y1': -4.81299212867367, 'x2': 131.12392824561778, 'y2': 292.2388139900753}
# drawing bbox for fg2410_215.jpg ---- {'x1': 259.5101261709008, 'y1': 341.95400023119635, 'x2': 421.01606937090077, 'y2': 570.3674554311963}
# drawing bbox for fg2410_215.jpg ---- {'x1': 135.5166724378821, 'y1': 336.4037839752196, 'x2': 348.02449243788215, 'y2': 636.9478039752196}
# drawing bbox for fg2410_215.jpg ---- {'x1': 550.9831302075914, 'y1': -8.618114094999726, 'x2': 741.4526680867161, 'y2': 260.7577639396739}
# drawing bbox for fg2410_215.jpg ---- {'x1': 431.66317035990045, 'y1': 500.58155717583406, 'x2': 653.8776312188792, 'y2': 814.8534148829533}
# drawing bbox for fg2410_215.jpg ---- {'x1': 35.62450659516003, 'y1': -36.95263364241049, 'x2': 228.79773753678342, 'y2': 236.24700382779588}
# [OK] Saved image with boxes: idml_bboxs\fg2410_215.jpg
